# %%
# # only for colab
# from google.colab import drive
# import os
# drive.mount("/content/gdrive")
# os.chdir('/content/gdrive/MyDrive/Projects/TESS/model_conditional_norm_flow/')
# ! ls

# %%
# ! rm -r log*

# %%
# Adapted from here: https://github.com/yolu1055/conditional-glow/tree/master

# %%
# @title Utils
import os
import torch
import numpy as np

def split_feature(tensor, type="split"):
    """
    type = ["split", "cross"]
    """
    C = tensor.size(1)
    if type == "split":
        return tensor[:, :C // 2, ...], tensor[:, C // 2:, ...]
    elif type == "cross":
        return tensor[:, 0::2, ...], tensor[:, 1::2, ...]


def save_model(model, optim, scheduler, dir, iteration):
    path = os.path.join(dir, "checkpoint_{}.pth.tar".format(iteration))
    state = {}
    state["iteration"] = iteration
    state["modelname"] = model.__class__.__name__
    state["model"] = model.state_dict()
    state["optim"] = optim.state_dict()
    if scheduler is not None:
        state["scheduler"] = scheduler.state_dict()
    else:
        state["scheduler"] = None

    torch.save(state, path)


def load_state(path, cuda):
    if cuda:
        print ("load to gpu")
        state = torch.load(path)
    else:
        print ("load to cpu")
        state = torch.load(path, map_location=lambda storage, loc: storage)

    return state


def _fast_hist(label_true, label_pred, n_class):
    mask = (label_true >= 0) & (label_true < n_class)
    hist = np.bincount(
        n_class * label_true[mask].astype(int) +
        label_pred[mask].astype(int), minlength=n_class ** 2).reshape(n_class, n_class)
    return hist

def compute_accuracy(label_trues, label_preds, n_class):

    hist = np.zeros((n_class, n_class))
    for lt, lp in zip(label_trues, label_preds):
        hist += _fast_hist(lt.flatten(), lp.flatten(), n_class)
    acc = np.diag(hist).sum() / hist.sum()
    acc_cls = np.diag(hist) / hist.sum(axis=1)
    acc_cls = np.nanmean(acc_cls)
    iu = np.diag(hist) / (hist.sum(axis=1) + hist.sum(axis=0) - np.diag(hist))
    mean_iu = np.nanmean(iu)
    freq = hist.sum(axis=1) / hist.sum()
    fwavacc = (freq[freq > 0] * iu[freq > 0]).sum()
    return acc, acc_cls, mean_iu, fwavacc


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
# @title Modules
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np


class ActNorm(nn.Module):

    def __init__(self, num_channels):
        super().__init__()

        size = [1, num_channels, 1, 1]

        bias = torch.normal(mean=torch.zeros(*size), std=torch.ones(*size)*0.05)
        logs = torch.normal(mean=torch.zeros(*size), std=torch.ones(*size)*0.05)
        self.register_parameter("bias", nn.Parameter(torch.Tensor(bias), requires_grad=True))
        self.register_parameter("logs", nn.Parameter(torch.Tensor(logs), requires_grad=True))


    def forward(self, input, logdet=0, reverse=False):
        dimentions = input.size(2) * input.size(3)
        if reverse == False:
            input = input + self.bias
            input = input * torch.exp(self.logs)
            dlogdet = torch.sum(self.logs) * dimentions
            logdet = logdet + dlogdet

        if reverse == True:
            input = input * torch.exp(-self.logs)
            input = input - self.bias
            dlogdet = - torch.sum(self.logs) * dimentions
            logdet = logdet + dlogdet

        return input, logdet


class Conv2dZeros(nn.Conv2d):

    def __init__(self, in_channel, out_channel, kernel_size=[3,3], stride=[1,1]):
        padding = (kernel_size[0] - 1) // 2
        super().__init__(in_channels=in_channel, out_channels=out_channel, kernel_size=kernel_size, stride=stride, padding=padding)
        self.weight.data.normal_(mean=0.0, std=0.1)


class Conv1dZeros(nn.Conv1d):

    def __init__(self, in_channel, out_channel, kernel_size=[1], stride=[1]):
        padding = (kernel_size[0] - 1) // 2
        super().__init__(in_channels=in_channel, out_channels=out_channel, kernel_size=kernel_size, stride=stride, padding=padding)
        self.weight.data.normal_(mean=0.0, std=0.1)


class Conv2dResize(nn.Conv2d):

    def __init__(self, in_size, out_size):

        stride = [in_size[1]//out_size[1], in_size[2]//out_size[2]]
        kernel_size = Conv2dResize.compute_kernel_size(in_size, out_size, stride)
        super().__init__(in_channels=in_size[0], out_channels=out_size[0], kernel_size=kernel_size, stride=stride)
        self.weight.data.zero_()


    @staticmethod
    def compute_kernel_size(in_size, out_size, stride):
        k0 = in_size[1] - (out_size[1] - 1) * stride[0]
        k1 = in_size[2] - (out_size[2] - 1) * stride[1]
        return[k0,k1]


class Conv1dResize(nn.Conv1d):

    def __init__(self, in_size, out_size):

        stride = [in_size[1]//out_size[1]]
        kernel_size = Conv1dResize.compute_kernel_size(in_size, out_size, stride)
        super().__init__(in_channels=in_size[0], out_channels=out_size[0], kernel_size=kernel_size, stride=stride)
        self.weight.data.zero_()


    @staticmethod
    def compute_kernel_size(in_size, out_size, stride):
        k0 = in_size[1] - (out_size[1] - 1) * stride[0]
        return[k0]


class Conv2dNorm(nn.Conv2d):

    def __init__(self, in_channels, out_channels, kernel_size=[3, 3], stride=[1, 1]):

        padding = (kernel_size[0] - 1) // 2
        super().__init__(in_channels, out_channels, kernel_size, stride, padding)
        #initialize weight
        self.weight.data.normal_(mean=0.0, std=0.05)


class Conv1dNorm(nn.Conv1d):

    def __init__(self, in_channels, out_channels, kernel_size=[1], stride=[1]):

        padding = (kernel_size[0] - 1) // 2
        super().__init__(in_channels, out_channels, kernel_size, stride, padding)
        #initialize weight
        self.weight.data.normal_(mean=0.0, std=0.05)


class CondActNorm(nn.Module):

    def __init__(self, x_size, y_channels, x_hidden_channels, x_hidden_size):
        super().__init__()

        C_x,H_x = x_size

        # conditioning network
        self.x_Con = nn.Sequential(
            Conv1dResize(in_size=[C_x,H_x], out_size=[x_hidden_channels, H_x//1]),
            nn.ReLU(),
            Conv1dResize(in_size=[x_hidden_channels, H_x//1], out_size=[x_hidden_channels, H_x//2]),
            nn.ReLU(),
            Conv1dResize(in_size=[x_hidden_channels, H_x//2], out_size=[x_hidden_channels, H_x//2]),
            nn.ReLU(),
            Conv1dResize(in_size=[x_hidden_channels, H_x//2], out_size=[x_hidden_channels, H_x//2]),
            nn.ReLU()
        )

        self.x_Linear = nn.Sequential(
            LinearZeros(x_hidden_channels*H_x//(2), x_hidden_size),
            nn.ReLU(),
            LinearZeros(x_hidden_size, x_hidden_size),
            nn.ReLU(),
            LinearZeros(x_hidden_size, 2*y_channels),
            nn.Tanh()
        )


    def forward(self, x, y, logdet=0, reverse=False):

        B,C,H = x.size()

        # generate weights 
        x = self.x_Con(x)
        x = x.view(B, -1)
        x = self.x_Linear(x)
        x = x.view(B, -1, 1, 1)



        logs, bias = split_feature(x)
        dimentions = y.size(2) * y.size(3)


        if not reverse:
            # center and scale
            y = y + bias
            y = y * torch.exp(logs)
            dlogdet = dimentions * torch.sum(logs, dim=(1,2,3))
            logdet = logdet + dlogdet
        else:
            # scale and center
            y = y * torch.exp(-logs)
            y = y - bias
            dlogdet = - dimentions * torch.sum(logs, dim=(1,2,3))
            logdet = logdet + dlogdet

        return y, logdet



class Cond1x1Conv(nn.Module):

    def __init__(self, x_size, x_hidden_channels, x_hidden_size, y_channels):

        super().__init__()

        C_x,H_x = x_size


        # conditioning network
        self.x_Con = nn.Sequential(
            Conv1dResize(in_size=[C_x,H_x], out_size=[x_hidden_channels, H_x//1]),
            nn.ReLU(),
            Conv1dResize(in_size=[x_hidden_channels, H_x//1], out_size=[x_hidden_channels, H_x//2]),
            nn.ReLU(),
            Conv1dResize(in_size=[x_hidden_channels, H_x//2], out_size=[x_hidden_channels, H_x//2]),
            nn.ReLU(),
            Conv1dResize(in_size=[x_hidden_channels, H_x//2], out_size=[x_hidden_channels, H_x//2]),
            nn.ReLU()
        )

        self.x_Linear = nn.Sequential(
            LinearZeros(x_hidden_channels*H_x//(2), x_hidden_size),
            nn.ReLU(),
            LinearZeros(x_hidden_size, x_hidden_size),
            nn.ReLU(),
            LinearNorm(x_hidden_size, y_channels*y_channels),
            nn.Tanh()
        )


    def get_weight(self, x, y, reverse):
        y_channels = y.size(1)
        B,C,H = x.size()

        x = self.x_Con(x)
        x = x.view(B, -1)
        x = self.x_Linear(x)
        weight = x.view(B, y_channels, y_channels)

        dimensions = y.size(2) * y.size(3)
        dlogdet = torch.slogdet(weight)[1] * dimensions


        if reverse == False:
            weight = weight.view(B, y_channels, y_channels,1,1)

        else:
            weight = torch.inverse(weight.double()).float().view(B, y_channels, y_channels,1,1)

        return weight, dlogdet



    def forward(self, x, y, logdet=None, reverse=False):

        weight, dlogdet = self.get_weight(x, y, reverse)
        B,C,H,W = y.size()
        y = y.view(1, B*C, H, W)
        B_k, C_i_k, C_o_k, H_k, W_k = weight.size()
        assert B == B_k and C == C_i_k and C == C_o_k, "The input and kernel dimensions are different"
        weight = weight.reshape(B_k*C_i_k,C_o_k,H_k,W_k)

        if reverse == False:
            z = F.conv2d(y, weight, groups=B)
            z = z.view(B,C,H,W)
            if logdet is not None:
                logdet = logdet + dlogdet

            return z, logdet
        else:
            z = F.conv2d(y, weight, groups=B)
            z = z.view(B,C,H,W)

            if logdet is not None:
                logdet = logdet - dlogdet

            return z, logdet


class Conv2dNormy(nn.Conv2d):

    def __init__(self, in_channels, out_channels,
                 kernel_size=[3, 3], stride=[1, 1]):
        padding = [(kernel_size[0]-1)//2, (kernel_size[1]-1)//2]
        super().__init__(in_channels, out_channels, kernel_size, stride,
                         padding, bias=False)

        #initialize weight
        self.weight.data.normal_(mean=0.0, std=0.05)
        self.actnorm = ActNorm(out_channels)


    def forward(self, input):
        x = super().forward(input)
        x,_ = self.actnorm(x)
        return x


class Conv2dZerosy(nn.Conv2d):

    def __init__(self, in_channels, out_channels,
                 kernel_size=[3, 3], stride=[1, 1]):

        padding = [(kernel_size[0]-1)//2, (kernel_size[1]-1)//2]
        super().__init__(in_channels, out_channels, kernel_size, stride, padding)

        self.logscale_factor = 3.0
        self.register_parameter("logs", nn.Parameter(torch.zeros(out_channels, 1, 1)))
        self.register_parameter("newbias", nn.Parameter(torch.zeros(out_channels, 1, 1)))

        # init
        self.weight.data.zero_()
        self.bias.data.zero_()

    def forward(self, input):
        output = super().forward(input)
        output = output + self.newbias
        output = output * torch.exp(self.logs * self.logscale_factor)
        return output




class CondAffineCoupling(nn.Module):

    def __init__(self, x_size, y_size, hidden_channels):
        super().__init__()

        self.resize_x = nn.Sequential(
            Conv1dZeros(x_size[0], 32),
            nn.ReLU(),
            Conv1dZeros(32, 16),
            nn.ReLU(),
            Conv1dResize((16,x_size[1]), out_size=y_size),
            nn.ReLU(),
            Conv1dZeros(y_size[0], y_size[0]*y_size[1]),
            nn.ReLU()
        )

        self.f = nn.Sequential(
            Conv2dNormy(y_size[0]*2, hidden_channels),
            nn.ReLU(),
            Conv2dNormy(hidden_channels, hidden_channels, kernel_size=[1, 1]),
            nn.ReLU(),
            Conv2dZerosy(hidden_channels, 2*y_size[0]),
            nn.Tanh()
        )


    def forward(self, x, y, logdet=0.0, reverse=False):

        z1, z2 = split_feature(y, "split")
        x = self.resize_x(x)

        x = x.view(z1.shape)

        h = torch.cat((x,z1), dim=1)
        h = self.f(h)
        shift, scale = split_feature(h, "cross")
        scale = torch.sigmoid(scale + 2.)
        if reverse == False:
            z2 = z2 + shift
            z2 = z2 * scale
            logdet = torch.sum(torch.log(scale), dim=(1, 2, 3)) + logdet

        if reverse == True:
            z2 = z2 / scale
            z2 = z2 - shift
            logdet = -torch.sum(torch.log(scale), dim=(1, 2, 3)) + logdet

        z = torch.cat((z1, z2), dim=1)

        return z, logdet



class SqueezeLayer(nn.Module):
    def __init__(self, factor):
        super().__init__()
        self.factor = factor

    def forward(self, input, logdet=None, reverse=False):
        if not reverse:
            output = SqueezeLayer.squeeze2d(input, self.factor)
            return output, logdet
        else:
            output = SqueezeLayer.unsqueeze2d(input, self.factor)
            return output, logdet


    @staticmethod
    def squeeze2d(input, factor=2):
        assert factor >= 1 and isinstance(factor, int)
        if factor == 1:
            return input
        B, C, H, W = input.size()
        assert H % factor == 0 and W % factor == 0, "{}".format((H, W))
        x = input.view(B, C, H // factor, factor, W // factor, factor)
        x = x.permute(0, 1, 3, 5, 2, 4).contiguous()
        x = x.view(B, C * factor * factor, H // factor, W // factor)
        return x


    @staticmethod
    def unsqueeze2d(input, factor=2):
        assert factor >= 1 and isinstance(factor, int)
        factor2 = factor ** 2
        if factor == 1:
            return input
        B, C, H, W = input.size()
        assert C % (factor2) == 0, "{}".format(C)
        x = input.view(B, C // factor2, factor, factor, H, W)
        x = x.permute(0, 1, 4, 2, 5, 3).contiguous()
        x = x.view(B, C // (factor2), H * factor, W * factor)
        return x


class Split2d(nn.Module):
    def __init__(self, num_channels):
        super().__init__()

        self.conv = nn.Sequential(
            Conv2dZeros(num_channels // 2, num_channels),
            nn.Tanh()
        )

    def split2d_prior(self, z):
        h = self.conv(z)
        return split_feature(h, "cross")

    def forward(self, input, logdet=0., reverse=False, eps_std=None):
        if not reverse:
            z1, z2 = split_feature(input, "split")
            mean, logs = self.split2d_prior(z1)
            logdet = GaussianDiag.logp(mean, logs, z2) + logdet

            return z1, logdet
        else:
            z1 = input
            mean, logs = self.split2d_prior(z1)
            z2 = GaussianDiag.sample(mean, logs, eps_std)
            z = torch.cat((z1, z2), dim=1)

            return z, logdet


class GaussianDiag:
    Log2PI = float(np.log(2 * np.pi))

    @staticmethod
    def likelihood(mean, logs, x):
        return -0.5 * (logs * 2. + ((x - mean) ** 2.) / torch.exp(logs * 2.) + GaussianDiag.Log2PI)

    @staticmethod
    def logp(mean, logs, x):
        likelihood = GaussianDiag.likelihood(mean, logs, x)
        return torch.sum(likelihood, dim=(1, 2, 3))

    @staticmethod
    def sample(mean, logs, eps_std=None):
        eps_std = eps_std or 1
        eps = torch.normal(mean=torch.zeros_like(mean),
                           std=torch.ones_like(logs) * eps_std)
        return mean + torch.exp(logs) * eps

    @staticmethod
    def batchsample(batchsize, mean, logs, eps_std=None):
        eps_std = eps_std or 1
        sample = GaussianDiag.sample(mean, logs, eps_std)
        for i in range(1, batchsize):
            s = GaussianDiag.sample(mean, logs, eps_std)
            sample = torch.cat((sample, s), dim=0)
        return sample



class LinearZeros(nn.Linear):

    def __init__(self, in_channels, out_channels):
        super().__init__(in_channels, out_channels)
        self.weight.data.zero_()
        self.bias.data.zero_()

    def forward(self, input):
        output = super().forward(input)
        return output


class LinearNorm(nn.Linear):

    def __init__(self, in_channels, out_channels):
        super().__init__(in_channels, out_channels)
        self.weight.data.normal_(mean=0.0, std=0.1)
        self.bias.data.normal_(mean=0.0, std=0.1)

# %%
# @title Glow Model
import torch
import torch.nn as nn
import numpy as np

class CondGlowStep(nn.Module):

    def __init__(self, x_size, y_size, x_hidden_channels, x_hidden_size, y_hidden_channels):


        super().__init__()

        # 1. cond-actnorm
        self.actnorm = CondActNorm(x_size=x_size, y_channels=y_size[0], x_hidden_channels=x_hidden_channels, x_hidden_size=x_hidden_size)

        # 2. cond-1x1conv
        self.invconv = Cond1x1Conv(x_size=x_size, x_hidden_channels=x_hidden_channels, x_hidden_size=x_hidden_size, y_channels=y_size[0])

        # 3. cond-affine
        self.affine = CondAffineCoupling(x_size=x_size, y_size=[y_size[0] // 2, y_size[1], y_size[2]], hidden_channels=y_hidden_channels)


    def forward(self, x, y, logdet=None, reverse=False):
        
        if reverse is False:
            # 1. cond-actnorm
            y, logdet = self.actnorm(x, y, logdet, reverse=False)

            # 2. cond-1x1conv
            y, logdet = self.invconv(x, y, logdet, reverse=False)

            # 3. cond-affine
            y, logdet = self.affine(x, y, logdet, reverse=False)

            # Return
            return y, logdet


        if reverse is True:
            # 3. cond-affine
            y, logdet = self.affine(x, y, logdet, reverse=True)

            # 2. cond-1x1conv
            y, logdet = self.invconv(x, y, logdet, reverse=True)

            # 1. cond-actnorm
            y, logdet = self.actnorm(x, y, logdet, reverse=True)

            # Return
            return y, logdet


class CondGlow(nn.Module):

    def __init__(self, x_size, y_size, x_hidden_channels, x_hidden_size, y_hidden_channels, K, L):


        super().__init__()
        self.layers = nn.ModuleList()
        self.output_shapes = []
        self.K = K
        self.L = L
        C, H, W = y_size

        for l in range(0, L):

            # 1. Squeeze
            C, H, W = C * 4, H // 2, W // 2
            y_size = [C,H,W]
            self.layers.append(SqueezeLayer(factor=2))
            self.output_shapes.append([-1, C, H, W])

            # 2. K CGlowStep
            for k in range(0, K):

                self.layers.append(CondGlowStep(x_size = x_size,
                                            y_size = y_size,
                                            x_hidden_channels = x_hidden_channels,
                                            x_hidden_size = x_hidden_size,
                                            y_hidden_channels = y_hidden_channels,
                                            )
                                   )

                self.output_shapes.append([-1, C, H, W])

            # 3. Split
            if l < L - 1:
                self.layers.append(Split2d(num_channels=C))
                self.output_shapes.append([-1, C // 2, H, W])
                C = C // 2


    def forward(self, x, y, logdet=0.0, reverse=False, eps_std=1.0):
        if reverse == False:
            return self.encode(x, y, logdet)
        else:
            return self.decode(x, y, logdet, eps_std)

    def encode(self, x, y, logdet=0.0):
        for layer, shape in zip(self.layers, self.output_shapes):
            if isinstance(layer, Split2d) or isinstance(layer, SqueezeLayer):
                y, logdet = layer(y, logdet, reverse=False)

            else:
                y, logdet = layer(x, y, logdet, reverse=False)
        return y, logdet

    def decode(self, x, y, logdet=0.0, eps_std=1.0):
        for layer in reversed(self.layers):
            if isinstance(layer, Split2d):
                y, logdet = layer(y, logdet=logdet, reverse=True, eps_std=eps_std)

            elif isinstance(layer, SqueezeLayer):
                y, logdet = layer(y, logdet=logdet, reverse=True)

            else:
                y, logdet = layer(x, y, logdet=logdet, reverse=True)

        return y, logdet


class CondGlowModel(nn.Module):
    BCE = nn.BCEWithLogitsLoss()
    CE = nn.CrossEntropyLoss()

    def __init__(self, args):
        super().__init__()
        self.flow = CondGlow(x_size=args.x_size,
                            y_size=args.y_size,
                            x_hidden_channels=args.x_hidden_channels,
                            x_hidden_size=args.x_hidden_size,
                            y_hidden_channels=args.y_hidden_channels,
                            K=args.depth_flow,
                            L=args.num_levels,
                            )

        self.learn_top = args.learn_top


        self.register_parameter("new_mean",
                                nn.Parameter(torch.zeros(
                                    [1,
                                     self.flow.output_shapes[-1][1],
                                     self.flow.output_shapes[-1][2],
                                     self.flow.output_shapes[-1][3]])))


        self.register_parameter("new_logs",
                                nn.Parameter(torch.zeros(
                                    [1,
                                     self.flow.output_shapes[-1][1],
                                     self.flow.output_shapes[-1][2],
                                     self.flow.output_shapes[-1][3]])))

        self.n_bins = args.y_bins


    def prior(self):

        if self.learn_top:
            return self.new_mean, self.new_logs
        else:
            return torch.zeros_like(self.new_mean), torch.zeros_like(self.new_logs)


    def forward(self, x=0.0, y=None, eps_std=1.0, reverse=False):
        if reverse == False:
            dimensions = y.size(1)*y.size(2)*y.size(3)
            logdet = torch.zeros_like(y[:, 0, 0, 0])
            logdet += float(-np.log(self.n_bins) * dimensions)
            z, objective = self.flow(x, y, logdet=logdet, reverse=False)
            mean, logs = self.prior()
            objective += GaussianDiag.logp(mean, logs, z)
            nll = -objective / float(np.log(2.) * dimensions)
            return z, nll

        else:
            with torch.no_grad():
                mean, logs = self.prior()
                if y is None:
                    y = GaussianDiag.batchsample(x.size(0), mean, logs, eps_std)
                y, logdet = self.flow(x, y, eps_std=eps_std, reverse=True)
            return y, logdet

# %%
# @title Learner
import os
import torch
import datetime
import numpy as np
from torch.utils.data import DataLoader
import time
# from datasets import convert_to_img
# from datasets import preprocess
# from datasets import postprocess
from torchvision.utils import save_image
import matplotlib.pyplot as plt


class Trainer(object):

    def __init__(self, graph, optim, scheduler, trainingset, validset, args, cuda):

        # set path and date
        date = str(datetime.datetime.now())
        date = date[:date.rfind(":")].replace("-", "")\
                                     .replace(":", "")\
                                     .replace(" ", "_")
        self.log_dir = os.path.join(args.log_root, "log_" + date)
        if not os.path.exists(self.log_dir):
            os.makedirs(self.log_dir)


        self.checkpoints_dir = os.path.join(self.log_dir, "checkpoints")
        if not os.path.exists(self.checkpoints_dir):
            os.makedirs(self.checkpoints_dir)

        # # old directories for samples and inverses
        # self.images_dir = os.path.join(self.log_dir, "images_training_set")
        # if not os.path.exists(self.images_dir):
        #     os.makedirs(self.images_dir)
        # self.valid_samples_dir = os.path.join(self.log_dir, "valid_samples")
        # if not os.path.exists(self.valid_samples_dir):
        #     os.makedirs(self.valid_samples_dir)

        # new directories

        # # do not need anymore, combined inverse into samples
        # # images_dir -> images_inverse_train_dir
        # self.images_inverse_train_dir = os.path.join(self.log_dir, "images_inverse_train")
        # if not os.path.exists(self.images_inverse_train_dir):
        #     os.makedirs(self.images_inverse_train_dir)
        # self.images_inverse_valid_dir = os.path.join(self.log_dir, "images_inverse_valid")
        # if not os.path.exists(self.images_inverse_valid_dir):
        #     os.makedirs(self.images_inverse_valid_dir)

        # valid_samples_dir -> images_samples_valid_dir
        self.images_samples_valid_dir = os.path.join(self.log_dir, "images_samples_valid")
        if not os.path.exists(self.images_samples_valid_dir):
            os.makedirs(self.images_samples_valid_dir)

        self.images_samples_train_dir = os.path.join(self.log_dir, "images_samples_train")
        if not os.path.exists(self.images_samples_train_dir):
            os.makedirs(self.images_samples_train_dir)



        # model
        self.graph = graph
        self.optim = optim
        self.scheduler = scheduler

        # gradient bound
        self.max_grad_clip = args.max_grad_clip
        self.max_grad_norm = args.max_grad_norm

        # data
        self.dataset_name = args.dataset_name
        self.batch_size = args.batch_size
        self.trainingset_loader = DataLoader(trainingset,
                                      batch_size=self.batch_size,
                                      shuffle=True,
                                      drop_last=True)

        self.validset_loader = DataLoader(validset,
                                      batch_size=self.batch_size,
                                      shuffle=False,
                                      drop_last=False)

        print('training, validation lengths: ', len(self.trainingset_loader), len(self.validset_loader))

        self.num_epochs = args.num_epochs
        self.global_step = args.num_steps
        self.label_scale = args.label_scale
        self.label_bias = args.label_bias
        self.x_bins = args.x_bins
        self.y_bins = args.y_bins


        self.num_epochs = args.num_epochs
        self.nll_gap = args.nll_gap
        self.inference_gap = args.inference_gap
        self.checkpoints_gap = args.checkpoints_gap
        self.save_gap = args.save_gap

        # device
        self.cuda = cuda

    def validate(self):
        print ("Start Validating")
        self.graph.eval()

        # for validation set
        mean_loss = list()
        samples = list()
        samples_ffi_nums = list()
        samples_x = list()
        samples_orbit = list()
        with torch.no_grad():
            for i_batch, batch in enumerate(self.validset_loader):
                
                x = batch["x"]
                y = batch["y"]
                ffi_num = batch["ffi_num"]
                orbit = batch["orbit"]

                if self.cuda:
                    x = x.cuda()
                    y = y.cuda()


                # forward
                z, nll = self.graph(x,y)
                loss = torch.mean(nll)
                mean_loss.append(loss.data.cpu().item())

                # true label
                y_true = y

                # sample
                batch_samples = []
                batch_samples_ffi_num = []
                batch_samples_x = []
                batch_samples_orbit = []
                for b in range(len(y)):
                    row = []
                    row.append(y_true[b])
                    batch_samples.append(row)

                    batch_samples_ffi_num.append([ffi_num[b]])
                    batch_samples_x.append([x[b]])
                    batch_samples_orbit.append([orbit[b]])
                    
                for i in range(0, 5):
                    y_sample,_ = self.graph(x, y=None, reverse=True)

                    for b in range(len(y)):
                        batch_samples[b].append(y_sample[b])

                        batch_samples_ffi_num[b].append(ffi_num[b])
                        batch_samples_x[b].append(x[b])
                        batch_samples_orbit[b].append(orbit[b])

                for b in range(len(y)):
                    samples.append(batch_samples[b])
                    samples_ffi_nums.append(batch_samples_ffi_num[b])
                    samples_x.append(batch_samples_x[b])
                    samples_orbit.append(batch_samples_orbit[b])
                    
        # save samples
        for i in range(0, len(samples)):
            if i < 5:
                fig, axes = plt.subplots(1, len(samples[i]), figsize=(40, 7))
                for b in range(0,len(samples[i])):
                    
                    # create title
                    ffi = samples_ffi_nums[i][b]
                    orbit = samples_orbit[i][b]
                    plottitle = ''
                    if b == 0: plottitle = 'y true: VALIDATION SET'
                    elif b == 1: plottitle = 'y inverse (use x and y)'
                    else: plottitle = f'(Using only x_cond) sample {b-1}'
                    data = [round(float(elt), 2) for elt in samples_x[i][b][0]]
                    data_line1 = str({'1/ED':data[0], '1/MD':data[1], '1/ED^2':data[2], '1/MD^2':data[3]})
                    data_line2 = str({'Eel':data[4], 'Eaz':data[5], 'Mel':data[6], 'Maz':data[7]})
                    data_line3 = str({'E3el':data[8], 'E3az':data[9], 'M3el':data[10], 'M3az':data[11]})
                    plottitle += '\nffi: ' + ffi + ' , O' + orbit + '\n' + data_line1 + '\n' + data_line2 + '\n' + data_line3
                    axes[b].set_title(plottitle)

                    # plot plots
                    im_pred = axes[b].imshow(samples[i][b].cpu()[0], cmap="gray", vmin=0, vmax=1)
                    fig.colorbar(im_pred, fraction=0.046, pad=0.04)
                fig.savefig(os.path.join(self.images_samples_valid_dir, f"valid_global_step{self.global_step}_sample{i}_batch{b}.pdf"))
                plt.close()

        # save loss
        mean = np.mean(mean_loss)
        with open(os.path.join(self.log_dir, "checkpoint_NLL_valid.txt"), "a") as nll_file:
            nll_file.write(str(self.global_step) + "\t" + "{:.5f}".format(mean) + "\n")

        
        print ("Finish Validating")
        self.graph.train()


    def train(self):

        self.graph.train()

        starttime = time.time()

        # for plotting training loss and predicitons on training set, done every checkpoint
        mean_loss = list()
        samples = list()
        samples_ffi_nums = list()
        samples_x = list()
        samples_orbit = list()

        # run
        num_batchs = len(self.trainingset_loader)
        total_its = self.num_epochs * num_batchs
        for epoch in range(self.num_epochs):
            mean_nll = 0.0
            for i_batch, batch in enumerate(self.trainingset_loader):
                
                self.optim.zero_grad()

                x = batch["x"]
                y = batch["y"]
                ffi_num = batch['ffi_num']
                orbit = batch['orbit']

                if self.cuda:
                    x = x.cuda()
                    y = y.cuda()

                # forward
                z, nll = self.graph(x, y)


                # loss
                loss = torch.mean(nll)
                mean_nll = mean_nll + loss.data

                # backward
                self.graph.zero_grad()
                self.optim.zero_grad()
                loss.backward()

                # operate grad
                if self.max_grad_clip > 0:
                    torch.nn.utils.clip_grad_value_(self.graph.parameters(), self.max_grad_clip)
                if self.max_grad_norm > 0:
                    torch.nn.utils.clip_grad_norm_(self.graph.parameters(), self.max_grad_norm)

                # step
                self.optim.step()

                currenttime = time.time()
                elapsed = currenttime - starttime
                print("Iteration: {}/{} \t Elapsed time: {:.2f} \t Loss:{:.5f}".format(self.global_step, total_its, elapsed, loss.data))

                if self.global_step % self.nll_gap == 0:
                    with open(os.path.join(self.log_dir, "step_NLL_train.txt"), "a") as nll_file:
                        nll_file.write(str(self.global_step) + " \t " + "{:.2f} \t {:.5f}".format(elapsed, loss.data) + "\n")



                # checkpoint
                if self.global_step % self.checkpoints_gap == 0 and self.global_step > 0:
                    self.validate()

                    # records training loss and predictions on training set
                    mean_loss = list()
                    samples = list()
                    samples_ffi_nums = list()
                    samples_x = list()
                    samples_orbit = list()
                    with torch.no_grad():

                        # have to do another trainingset_loader because we have to use torch.nograd()
                        # that turns off the gradient descent
                        for i_batch, batch in enumerate(self.trainingset_loader):
                            
                            mean_loss.append(loss.data.cpu().item())
            
                            # true label
                            y_true = y
            
                            # sample
                            batch_samples = []
                            batch_samples_ffi_num = []
                            batch_samples_x = []
                            batch_samples_orbit = []
                            for b in range(len(y)):
                                row = []
                                row.append(y_true[b])
                                batch_samples.append(row)
            
                                batch_samples_ffi_num.append([ffi_num[b]])
                                batch_samples_x.append([x[b]])
                                batch_samples_orbit.append([orbit[b]])
                                
                            for i in range(0, 5):
                                y_sample,_ = self.graph(x, y=None, reverse=True)
            
                                for b in range(len(y)):
                                    batch_samples[b].append(y_sample[b])
            
                                    batch_samples_ffi_num[b].append(ffi_num[b])
                                    batch_samples_x[b].append(x[b])
                                    batch_samples_orbit[b].append(orbit[b])
            
                            for b in range(len(y)):
                                samples.append(batch_samples[b])
                                samples_ffi_nums.append(batch_samples_ffi_num[b])
                                samples_x.append(batch_samples_x[b])
                                samples_orbit.append(batch_samples_orbit[b])
                                
                    # save samples
                    for i in range(0, len(samples)):
                        if i < 5:
                            fig, axes = plt.subplots(1, len(samples[i]), figsize=(40, 7))
                            for b in range(0,len(samples[i])):
                                
                                # create title
                                ffi = samples_ffi_nums[i][b]
                                orbit = samples_orbit[i][b]
                                plottitle = ''
                                if b == 0: plottitle = 'y true: TRAINING SET'
                                elif b == 1: plottitle = 'y inverse (use x and y)'
                                else: plottitle = f'(Using only x_cond) sample {b-1}'
                                data = [round(float(elt), 2) for elt in samples_x[i][b][0]]
                                data_line1 = str({'1/ED':data[0], '1/MD':data[1], '1/ED^2':data[2], '1/MD^2':data[3]})
                                data_line2 = str({'Eel':data[4], 'Eaz':data[5], 'Mel':data[6], 'Maz':data[7]})
                                data_line3 = str({'E3el':data[8], 'E3az':data[9], 'M3el':data[10], 'M3az':data[11]})
                                plottitle += '\nffi: ' + ffi + ' , O' + orbit + '\n' + data_line1 + '\n' + data_line2 + '\n' + data_line3
                                axes[b].set_title(plottitle)

                                # plot plots
                                im_pred = axes[b].imshow(samples[i][b].cpu()[0], cmap="gray", vmin=0, vmax=1)
                                fig.colorbar(im_pred, fraction=0.046, pad=0.04)
                            fig.savefig(os.path.join(self.images_samples_train_dir, f"train_global_step{self.global_step}_sample{i}_batch{b}.pdf"))
                            plt.close()
            
                    # save loss
                    mean = np.mean(mean_loss)
                    with open(os.path.join(self.log_dir, "checkpoint_NLL_train.txt"), "a") as nll_file:
                        nll_file.write(str(self.global_step) + "\t" + "{:.5f}".format(mean) + "\n")


                    # # samples
                    # samples = []
                    # for b in range(self.batch_size):
                    #     samples.append([])

                    # for i in range(0,5):
                    #     y_sample,_ = self.graph(x, y=None, reverse=True)
                    #     for b in range(self.batch_size):
                    #         samples[b].append(y_sample[b])

                    # # inverse image
                    # y_inverse,_ = self.graph(x, y=z, reverse=True)

                    # # true label
                    # y_true = y


                    # # save images
                    # output = None
                    # for b in range(0, self.batch_size):

                    #     fig, axes = plt.subplots(1, 3, figsize=(20, 8))

                    #     if b < 5:
                    #         angles_str = str([round(float(elt), 2) for elt in x[b][0]])
                    #         angles_title = str(['E3el', 'E3az', 'M3el', 'M3az', '1/ED', '1/MD', '1/ED^2', '1/MD^2'])
                    
                    #         axes[0].set_title('y Truth\nffi: ' + ffi_num[b] + ' , O' + orbit[b] + '\nangles: ' + angles_str + '\n' + angles_title)
                    #         im_true = axes[0].imshow(y[b].cpu()[0], cmap="gray", vmin=0, vmax=1)
                    #         fig.colorbar(im_true, fraction=0.046, pad=0.04)

                    #         axes[1].set_title('y inverse\nffi: ' + ffi_num[b] + ' , O' + orbit[b] + '\nangles: ' + angles_str + '\n' + angles_title)
                    #         im_latent = axes[1].imshow(y_inverse[b].cpu()[0], cmap="gray", vmin=0, vmax=1)
                    #         fig.colorbar(im_latent, fraction=0.046, pad=0.04)

                    #         axes[2].set_title('y Prediction sample\nffi: ' + ffi_num[b] + ' , O' + orbit[b] + '\nangles: ' + angles_str + '\n' + angles_title)
                    #         im_pred = axes[2].imshow(samples[b][i].cpu()[0], cmap="gray", vmin=0, vmax=1)
                    #         fig.colorbar(im_pred, fraction=0.046, pad=0.04)

                    #         fig.savefig(os.path.join(self.images_inverse_train_dir, f"global_step-{self.global_step}_batch_{b}.pdf"))
                    #         plt.close()



        
                    # plot loss graphs
                    def read_data(file_path):
                        data = {'x': [], 'y': []}
                        with open(file_path, 'r') as file:
                            for line in file:
                                x, y = map(float, line.strip().split())
                                data['x'].append(x)
                                data['y'].append(y)
                        return data
            
                    valid_loss = read_data(os.path.join(self.log_dir, "checkpoint_NLL_valid.txt"))
                    train_loss = read_data(os.path.join(self.log_dir, "checkpoint_NLL_train.txt"))
                    plt.plot(valid_loss['x'], valid_loss['y'], label='Validation NLL')
                    plt.plot(train_loss['x'], train_loss['y'], label='Training NLL')
                    plt.xlabel('Global step')
                    plt.ylabel('NLL')
                    plt.title('NLL: Training & Validation')
                    plt.legend()
                    plt.savefig(os.path.join(self.log_dir, "graph_NLL_valid_train.png"))
                    plt.close()
                

                # save model
                if self.global_step % self.save_gap == 0 and self.global_step > 0:
                    save_model(self.graph, self.optim, self.scheduler, self.checkpoints_dir, self.global_step)

                self.global_step = self.global_step + 1

            if self.scheduler is not None:
                self.scheduler.step()
            mean_nll = float(mean_nll / float(num_batchs))
            with open(os.path.join(self.log_dir, "epoch_NLL_train.txt"), "a") as f:
                currenttime = time.time()
                elapsed = currenttime - starttime
                f.write("{} \t {:.2f}\t {:.5f}".format(epoch, elapsed, mean_nll) + "\n")




class Inferencer(object):

    def __init__(self, model, dataset, args, cuda):

        # set path and date
        self.out_root = args.out_root
        if not os.path.exists(self.out_root):
            os.makedirs(self.out_root)

        # cuda
        self.cuda = cuda

        # model
        self.model = model


        # data
        self.dataset_name = args.dataset_name
        self.batch_size = args.batch_size
        self.data_loader = DataLoader(dataset,
                                      batch_size=self.batch_size,
                                      shuffle=False,
                                      drop_last=False)

        self.label_scale = args.label_scale
        self.label_bias = args.label_bias
        self.num_labels = args.num_labels
        self.y_bins = args.y_bins
        self.x_bins = args.x_bins


    def sampled_based_prediction(self, n_samples):
        metrics = []
        start = time.time()
        for i_batch, batch in enumerate(self.data_loader):
            print(f"Batch IDs: {i_batch}")

            x = batch["x"]
            y = batch["y"]
            ffi_num = batch['ffi_num']
            orbit = batch['orbit']

            if self.cuda:
                x = x.cuda()
                y = y.cuda()


            sample_list = list()
            nll_list = list()
            for i in range(0, n_samples):

                print(f"Samples: {i}/{n_samples}")

                # z, nll = self.model(x, y, reverse=False)
                # ypred, logdet = self.model(x, z, reverse=True)

                y_sample,_ = self.model(x, reverse=True)
                _, nll = self.model(x,y_sample)
                loss = torch.mean(nll)
                sample_list.append(y_sample)
                nll_list.append(loss.data.cpu().numpy())

            sample = torch.stack(sample_list)
            sample_mean = torch.mean(sample, dim=0, keepdim=False)
            sample_std = torch.std(sample, dim=0, keepdim=False)
            nll = np.mean(nll_list)

            y_pred_imgs_mean = sample_mean
            y_pred_imgs_std = sample_std
            y_true_imgs = y

            # save trues and preds using only xcond
            output = []
            for i in range(0, len(y_true_imgs)):
                true_img = y_true_imgs[i]
                pred_img = y_pred_imgs_mean[i]
                pred_img_std = y_pred_imgs_std[i]

                # print(sample.shape)

                fig, axes = plt.subplots(1, 3, figsize=(20, 8))
                xc = x[i].cpu()[0]

                angles_str = str([round(float(elt), 2) for elt in xc])
                angles_title = str(['E3el', 'E3az', 'M3el', 'M3az', '1/ED', '1/MD', '1/ED^2', '1/MD^2'])
                # print(f"E-el: {xc[0]}, E-az: {xc[1]}, M-el: {xc[2]}, M-az: {xc[3]}, 1/ED: {xc[4]}, 1/MD: {xc[5]}, 1/MD^2: {xc[6]}, 1/ED^2: {xc[7]}]")

                
                axes[0].set_title('Truth\nffi: ' + ffi_num[i] + ' , O' + orbit[i] + '\nangles: ' + angles_str + '\n' + angles_title)#, f"E-el: {xc[0]}, E-az: {xc[1]}, M-el: {xc[2]}, M-az: {xc[3]}, 1/ED: {xc[4]}, 1/MD: {xc[5]}, 1/MD^2: {xc[6]}, 1/ED^2: {xc[7]}")
                im_true = axes[0].imshow(true_img.cpu()[0], cmap="gray", vmin=0, vmax=1)
                fig.colorbar(im_true, fraction=0.046, pad=0.04)

                axes[1].set_title('Prediction mean (using only xcond)\nffi: ' + ffi_num[i] + ' , O' + orbit[i] + '\nangles: ' + angles_str + '\n' + angles_title)
                im_pred = axes[1].imshow(pred_img.cpu()[0], cmap="gray", vmin=0, vmax=1)
                fig.colorbar(im_pred, fraction=0.046, pad=0.04)

                # print(pred_img_std.cpu()[0])
                axes[2].set_title('Prediction std (using only xcond)\nffi: ' + ffi_num[i] + ', O' + orbit[i] + '\nangles: ' + angles_str + '\n' + angles_title)
                im_pred = axes[2].imshow(pred_img_std.cpu()[0], cmap="gray", vmin=0, vmax=1)
                fig.colorbar(im_pred, fraction=0.046, pad=0.04)

                fig.savefig(os.path.join(self.out_root, f"batch_xcond-{i_batch}-{i}.pdf"))
                plt.close()

            # Save plots using xcond and y
            z, nll = self.model(x, y)
            y_inverse, _ = self.model(x, y=z, reverse=True)

            for i in range(0, len(y)):
                true_img = y[i]
                pred_img = y_inverse[i]

                fig, axes = plt.subplots(1, 2, figsize=(20, 8))

                angles_str = str([round(float(elt), 2) for elt in x[i][0]])
                angles_title = str(['E3el', 'E3az', 'M3el', 'M3az', '1/ED', '1/MD', '1/ED^2', '1/MD^2'])

                axes[0].set_title('y Truth\nffi: ' + ffi_num[i] + ', O' + orbit[i] + '\nangles: ' + angles_str + '\n' + angles_title)
                im_true = axes[0].imshow(true_img.cpu()[0], cmap="gray", vmin=0, vmax=1)
                fig.colorbar(im_true, fraction=0.046, pad=0.04)

                axes[1].set_title('y inverse\nffi: ' + ffi_num[i] + ', O' + orbit[i] + '\nangles: ' + angles_str + '\n' + angles_title)
                im_latent = axes[1].imshow(pred_img.cpu()[0], cmap="gray", vmin=0, vmax=1)
                fig.colorbar(im_latent, fraction=0.046, pad=0.04)

                fig.savefig(os.path.join(self.out_root, f"batch_xandy-{i_batch}-{i}.pdf"))
                plt.close()

# %%
# # @title Datasets
# import os
# import numpy as np
# import torch
# import PIL.Image as Image
# from torch.utils import data
# import torchvision.transforms as transforms


# class HorseDataset(data.Dataset):

#     def __init__(self, dir, size, n_c, portion="train"):
#         self.dir = dir
#         self.names = self.read_names(dir, portion)
#         self.n_c = n_c
#         self.size = size

#     def read_names(self, dir, portion):

#         path = os.path.join(dir, "{}.txt".format(portion))
#         names = list()
#         with open(path, "r") as f:
#             for line in f:
#                 line = line.strip()
#                 name = {}
#                 name["img"] = os.path.join(dir, os.path.join("images", line))
#                 name["lbl"] = os.path.join(dir, os.path.join("labels", line))
#                 names.append(name)
#         return names

#     def __len__(self):
#         return len(self.names)


#     def __getitem__(self, index):

#         # path
#         name = self.names[index]
#         img_path = name["img"]
#         lbl_path = name["lbl"]
#         transform = transforms.Compose([transforms.Resize(self.size), transforms.ToTensor()])

#         # img
#         img = Image.open(img_path).convert("RGB")
#         img = transform(img)

#         # lbl
#         lbl = Image.open(lbl_path).convert("L")
#         lbl = transform(lbl)
#         lbl = torch.round(lbl)
#         if self.n_c > 1:
#             lbl = lbl.repeat(self.n_c,1,1)

#         return {"x":img, "y":lbl}

# %%
# @title TESS Dataset
import os
from PIL import Image
import torch
import pickle
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.transforms as transforms

class TESSDataset(Dataset):
    def __init__(self):

        # self.data = []
        # self.labels = []

        # get data
        angle_folder = "/pdo/users/jlupoiii/TESS/data/angles/"
        ccd_folder = "/pdo/users/jlupoiii/TESS/data/ccds_background_subtracted/"

        # data matrices
        X = []
        Y = []
        ffi_nums = []

        self.angles_dic = pickle.load(open(angle_folder+'angles_O13-14_19-20_data_dic.pkl', "rb"))
        # angles_dic = pickle.load(open(angle_folder+'angles_O13_data.pkl', "rb"))


        # self.ffi_num_to_orbit_dic = pickle.load(open(angle_folder+'ffi_num_to_orbit_dic.pkl', "rb"))

        for filename in os.listdir(ccd_folder):
            if len(filename) < 40 or filename[27] != '3': continue

            image_arr = pickle.load(open(ccd_folder+filename, "rb"))
            ffi_num = filename[18:18+8]
            try:
                angles = self.angles_dic[ffi_num]
                # print('Got ffi number', ffi_num)
            except:
                # print('Could not find ffi with number:', ffi_num)
                continue
            # X.append(np.array([angles[10], angles[11], angles[18], angles[19], angles[22], angles[23], angles[24], angles[25]]))
            X.append(np.array([angles['1/ED'], angles['1/MD'], angles['1/ED^2'], angles['1/MD^2'], angles['Eel'], angles['Eaz'], angles['Mel'], angles['Maz'], angles['E3el'], angles['E3az'], angles['M3el'], angles['M3az']]))

            Y.append(image_arr.flatten())
            ffi_nums.append(ffi_num)

        # for x in X:
        #     print(x)
        
        # X = np.array(X)
        # Y = np.array(Y)
        # ffis = np.array(ffis)
        # we are calculating Y GIVEN X
        self.data = [Image.fromarray(x) for x in X]
        self.labels = [Image.fromarray(y) for y in Y]
        self.ffi_nums = ffi_nums

        # for s in self.labels:
        #     print(s.size)
        #     # print(np.array(s).reshape((16,16))
            
        #     plt.imshow(np.array(s).reshape((16,16)))
        #     plt.show()
        #     plt.close()



        # for class_idx, class_name in enumerate(self.classes):
        #     # print(class_idx)
        #     horse_img_path = os.path.join(self.root_dir, "horse", class_name)
        #     mask_img_path = os.path.join(self.root_dir, "mask", class_name)

        #     horse_image = Image.open(horse_img_path).convert('RGB')
        #     mask_image = Image.open(mask_img_path).convert('L')

        #     self.data.extend([horse_image])
        #     self.labels.extend([mask_image])

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # horse_img_path, mask_img_path = self.data[idx], self.labels[idx]
        # label = self.labels[idx]
        # horse_image = Image.open(horse_img_path).convert('RGB')
        # mask_image = Image.open(mask_img_path).convert('L')

        angles_image = self.data[idx]
        ffi_image = self.labels[idx]
        ffi_num = self.ffi_nums[idx]
        # orbit = self.ffi_num_to_orbit_dic[ffi_num]
        orbit = self.angles_dic[ffi_num]["orbit"]

        transform = transforms.Compose([
            # transforms.Resize((1, 8)),
            transforms.ToTensor(),
            lambda s: s.reshape(1, 12),
            # transforms.Normalize(mean=[0.456], std=[0.225])
        ])
        target_transform = transforms.Compose([
            lambda s: np.array(s),
            lambda s: s.reshape((16,16)),
            # transforms.Resize((16, 16)),
            transforms.ToTensor()
        ])

        angles_image = transform(angles_image)
        ffi_image = target_transform(ffi_image)
        
        # return x=angles, y=ffis
        # we are calculating X GIVEN Y
        return {"x":angles_image, "y":ffi_image, "ffi_num": ffi_num, "orbit": orbit}

# %%
# MAKE DATASET

# we are calculating Y GIVEN X
tess_dataset = TESSDataset()
print(len(tess_dataset))
print(tess_dataset[1]['x'].shape)
print(tess_dataset[1]['y'].shape)
print(tess_dataset[1]['ffi_num'])
print(tess_dataset[1]['orbit'])

# plt.plot(tess_dataset[1]['x'][0])
print('x:', tess_dataset[1]['x'][0])

plt.imshow(tess_dataset[1]['y'][0], vmin=0, vmax=1)
plt.colorbar()
plt.show()
plt.close()

# # displays all datapoints
# for i in range(len(tess_dataset)):
#     print('------')
#     print('x:', tess_dataset[i]['x'][0])
#     plt.imshow(tess_dataset[i]['y'][0], vmin=0, vmax=1)
#     plt.colorbar()
#     plt.show()
#     plt.close()
# Out:
# 2296
# torch.Size([1, 12])
# torch.Size([1, 16, 16])
# 00012470
# 20
# x: tensor([ 0.9653,  0.4946,  0.9317,  0.2446, -0.9791, -1.0594, -0.9268, -0.1327,
#          2.4260,  5.4472,  2.2899,  6.1767])

# %%
# @title Train
import argparse
import torch
from torchvision import datasets
# import Learner
# import datasets
# import utils
# from CGlowModel import CondGlowModel


if __name__=="__main__":

    parser = argparse.ArgumentParser(description='train c-Glow')

    # input output path
    parser.add_argument("-d", "--dataset_name", type=str, default="horse")
    parser.add_argument("-r", "--dataset_root", type=str, default="weizmann_horse_db")

    # log root
    parser.add_argument("--log_root", type=str, default="")

    # C-Glow parameters
    # we are calculating Y GIVEN X
    parser.add_argument("--x_size", type=tuple, default=(1,12)) # was (1,8) before adding 4 more
    parser.add_argument("--y_size", type=tuple, default=(1,16,16))
    parser.add_argument("--x_hidden_channels", type=int, default=128)
    parser.add_argument("--x_hidden_size", type=int, default=64)
    parser.add_argument("--y_hidden_channels", type=int, default=256)
    parser.add_argument("-K", "--depth_flow", type=int, default=8)
    parser.add_argument("-L", "--num_levels", type=int, default=3)
    parser.add_argument("--learn_top", type=bool, default=False)

    # Dataset preprocess parameters
    parser.add_argument("--label_scale", type=float, default=1)
    parser.add_argument("--label_bias", type=float, default=0.5)
    parser.add_argument("--x_bins", type=float, default=256.0)
    parser.add_argument("--y_bins", type=float, default=2.0)


    # Optimizer parameters
    parser.add_argument("--optimizer", type=str, default="adam")
    parser.add_argument("--lr", type=float, default=0.0002)
    parser.add_argument("--betas", type=tuple, default=(0.9,0.9999))
    parser.add_argument("--eps", type=float, default=1e-8)
    parser.add_argument("--regularizer", type=float, default=0.0)
    parser.add_argument("--num_steps", type=int, default=0)

    # Trainer parameters
    parser.add_argument("--num_epochs", type=int, default=1000)
    parser.add_argument("--batch_size", type=int, default=2)
    parser.add_argument("--max_grad_clip", type=float, default=5)
    parser.add_argument("--max_grad_norm", type=float, default=0)
    parser.add_argument("--checkpoints_gap", type=int, default=10000) # typically 1000
    parser.add_argument("--nll_gap", type=int, default=1)
    parser.add_argument("--inference_gap", type=int, default=1000)
    parser.add_argument("--save_gap", type=int, default=1000)

    # model path
    parser.add_argument("--model_path", type=str, default="")#/pdo/users/jlupoiii/TESS/model_conditional_norm_flow/1D-angles-O13-image0to1_angle_rad/checkpoints/checkpoint_51000.pth.tar") #"/pdo/users/jlupoiii/TESS/model_conditional_norm_flow/log_20230821_2340/checkpoints/checkpoint_4000.pth.tar") # "/pdo/users/jlupoiii/TESS/model_conditional_norm_flow/log_20230821_2340/checkpoints/checkpoint_4000.pth.tar"
    
    # args = parser.parse_args()
    args = parser.parse_known_args()[0]
    cuda = torch.cuda.is_available()


    # # HORSE DATASET
    # dataset_root = 'weizmann_horse_db/'
    # # Define any image transformations you want to apply (resize, normalization, etc.)
    # transform = transforms.Compose([
    #     transforms.Resize((64, 64)),
    #     transforms.ToTensor(),
    #     # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    # ])
    # target_transform = transforms.Compose([
    #     transforms.Resize((64, 64)),
    #     transforms.ToTensor(),
    #     # transforms.Normalize(mean=[0.456], std=[0.225])
    # ])
    # # Create the dataset
    # training_set = WeizmannHorseDataset(root_dir=dataset_root, transform=transform, target_transform=target_transform)
    # valid_set = WeizmannHorseDataset(root_dir=dataset_root, transform=transform, target_transform=target_transform)

    # create TESS dataset
    torch.manual_seed(42)
    full_dataset = TESSDataset()
    train_ratio = 0.8
    num_train_samples = int(train_ratio * len(full_dataset))
    num_valid_samples = len(full_dataset) - num_train_samples
    training_set, valid_set = random_split(full_dataset, [num_train_samples, num_valid_samples])

    model = CondGlowModel(args)
    if cuda:
        model = model.cuda()

    # from utils import count_parameters
    print("number of param: {}".format(count_parameters(model)))

    # optimizer
    optim = torch.optim.Adam(model.parameters(), lr=args.lr,betas=args.betas, weight_decay=args.regularizer)

    # scheduler
    scheduler = None

    if args.model_path != "":
        state = load_state(args.model_path, cuda)
        optim.load_state_dict(state["optim"])
        model.load_state_dict(state["model"])
        args.steps = state["iteration"] + 1
        if scheduler is not None and state.get("scheduler", None) is not None:
            scheduler.load_state_dict(state["scheduler"])
        del state
        print('Realoaded model stored at', args.model_path, 'starting at step', args.steps)

    # begin to train
    trainer = Trainer(model, optim, scheduler, training_set, valid_set, args, cuda)
    trainer.train()
# Out:
# number of param: 8598596
# training, validation lengths:  918 230
# Iteration: 0/918000 	 Elapsed time: 4.39 	 Loss:43.48600
# Iteration: 1/918000 	 Elapsed time: 4.69 	 Loss:43.17210
# Iteration: 2/918000 	 Elapsed time: 4.88 	 Loss:42.94965
# Iteration: 3/918000 	 Elapsed time: 5.16 	 Loss:42.75171
# Iteration: 4/918000 	 Elapsed time: 5.34 	 Loss:42.56909
# Iteration: 5/918000 	 Elapsed time: 5.50 	 Loss:42.39753
# Iteration: 6/918000 	 Elapsed time: 5.73 	 Loss:42.23442
# Iteration: 7/918000 	 Elapsed time: 5.98 	 Loss:42.07811
# Iteration: 8/918000 	 Elapsed time: 6.17 	 Loss:41.92741
# Iteration: 9/918000 	 Elapsed time: 6.39 	 Loss:41.78140
# Iteration: 10/918000 	 Elapsed time: 6.58 	 Loss:41.63940
# Iteration: 11/918000 	 Elapsed time: 6.75 	 Loss:41.50080
# Iteration: 12/918000 	 Elapsed time: 6.92 	 Loss:41.36520
# Iteration: 13/918000 	 Elapsed time: 7.11 	 Loss:41.23222
# Iteration: 14/918000 	 Elapsed time: 7.28 	 Loss:41.10155
# Iteration: 15/918000 	 Elapsed time: 7.46 	 Loss:40.97282
# Iteration: 16/918000 	 Elapsed time: 7.64 	 Loss:40.84596
# Iteration: 17/918000 	 Elapsed time: 7.84 	 Loss:40.72057
# Iteration: 18/918000 	 Elapsed time: 8.50 	 Loss:40.59657
# Iteration: 19/918000 	 Elapsed time: 8.73 	 Loss:40.47383
# Iteration: 20/918000 	 Elapsed time: 9.02 	 Loss:40.35226
# Iteration: 21/918000 	 Elapsed time: 9.19 	 Loss:40.23182
# Iteration: 22/918000 	 Elapsed time: 9.38 	 Loss:40.11256
# Iteration: 23/918000 	 Elapsed time: 9.57 	 Loss:39.99448
# Iteration: 24/918000 	 Elapsed time: 9.79 	 Loss:39.87804
# Iteration: 25/918000 	 Elapsed time: 9.94 	 Loss:39.76300
# Iteration: 26/918000 	 Elapsed time: 10.12 	 Loss:39.64988
# Iteration: 27/918000 	 Elapsed time: 10.32 	 Loss:39.53872
# Iteration: 28/918000 	 Elapsed time: 10.49 	 Loss:39.42987
# Iteration: 29/918000 	 Elapsed time: 10.66 	 Loss:39.32359
# Iteration: 30/918000 	 Elapsed time: 10.84 	 Loss:39.21997
# Iteration: 31/918000 	 Elapsed time: 11.11 	 Loss:39.11916
# Iteration: 32/918000 	 Elapsed time: 11.30 	 Loss:39.02106
# Iteration: 33/918000 	 Elapsed time: 11.51 	 Loss:38.92567
# Iteration: 34/918000 	 Elapsed time: 11.70 	 Loss:38.83299
# Iteration: 35/918000 	 Elapsed time: 12.27 	 Loss:38.74296
# Iteration: 36/918000 	 Elapsed time: 12.44 	 Loss:38.65599
# Iteration: 37/918000 	 Elapsed time: 12.61 	 Loss:38.57164
# Iteration: 38/918000 	 Elapsed time: 12.78 	 Loss:38.48980
# Iteration: 39/918000 	 Elapsed time: 12.95 	 Loss:38.41010
# Iteration: 40/918000 	 Elapsed time: 13.12 	 Loss:38.33248
# Iteration: 41/918000 	 Elapsed time: 13.30 	 Loss:38.25644
# Iteration: 42/918000 	 Elapsed time: 13.48 	 Loss:38.18194
# Iteration: 43/918000 	 Elapsed time: 13.66 	 Loss:38.10886
# Iteration: 44/918000 	 Elapsed time: 13.83 	 Loss:38.03711
# Iteration: 45/918000 	 Elapsed time: 14.02 	 Loss:37.96657
# Iteration: 46/918000 	 Elapsed time: 14.17 	 Loss:37.89719
# Iteration: 47/918000 	 Elapsed time: 14.34 	 Loss:37.82872
# Iteration: 48/918000 	 Elapsed time: 14.57 	 Loss:37.76103
# Iteration: 49/918000 	 Elapsed time: 14.75 	 Loss:37.69418
# Iteration: 50/918000 	 Elapsed time: 14.92 	 Loss:37.62821
# Iteration: 51/918000 	 Elapsed time: 15.11 	 Loss:37.56303
# Iteration: 52/918000 	 Elapsed time: 15.29 	 Loss:37.49860
# Iteration: 53/918000 	 Elapsed time: 15.47 	 Loss:37.43475
# Iteration: 54/918000 	 Elapsed time: 15.63 	 Loss:37.37145
# Iteration: 55/918000 	 Elapsed time: 15.82 	 Loss:37.30875
# Iteration: 56/918000 	 Elapsed time: 16.03 	 Loss:37.24666
# Iteration: 57/918000 	 Elapsed time: 16.39 	 Loss:37.18510
# Iteration: 58/918000 	 Elapsed time: 16.63 	 Loss:37.12401
# Iteration: 59/918000 	 Elapsed time: 16.80 	 Loss:37.06337
# Iteration: 60/918000 	 Elapsed time: 16.98 	 Loss:37.00327
# Iteration: 61/918000 	 Elapsed time: 17.15 	 Loss:36.94363
# Iteration: 62/918000 	 Elapsed time: 17.33 	 Loss:36.88449
# Iteration: 63/918000 	 Elapsed time: 17.52 	 Loss:36.82573
# Iteration: 64/918000 	 Elapsed time: 17.70 	 Loss:36.76739
# Iteration: 65/918000 	 Elapsed time: 17.89 	 Loss:36.70948
# Iteration: 66/918000 	 Elapsed time: 18.31 	 Loss:36.65199
# Iteration: 67/918000 	 Elapsed time: 18.49 	 Loss:36.59489
# Iteration: 68/918000 	 Elapsed time: 18.66 	 Loss:36.53814
# Iteration: 69/918000 	 Elapsed time: 19.23 	 Loss:36.48179
# Iteration: 70/918000 	 Elapsed time: 19.40 	 Loss:36.42581
# Iteration: 71/918000 	 Elapsed time: 19.59 	 Loss:36.37019
# Iteration: 72/918000 	 Elapsed time: 19.77 	 Loss:36.31490
# Iteration: 73/918000 	 Elapsed time: 19.95 	 Loss:36.25998
# Iteration: 74/918000 	 Elapsed time: 20.12 	 Loss:36.20541
# Iteration: 75/918000 	 Elapsed time: 20.30 	 Loss:36.15117
# Iteration: 76/918000 	 Elapsed time: 20.46 	 Loss:36.09724
# Iteration: 77/918000 	 Elapsed time: 20.65 	 Loss:36.04364
# Iteration: 78/918000 	 Elapsed time: 20.82 	 Loss:35.99035
# Iteration: 79/918000 	 Elapsed time: 20.99 	 Loss:35.93737
# Iteration: 80/918000 	 Elapsed time: 21.39 	 Loss:35.88468
# Iteration: 81/918000 	 Elapsed time: 21.62 	 Loss:35.83230
# Iteration: 82/918000 	 Elapsed time: 21.78 	 Loss:35.78019
# Iteration: 83/918000 	 Elapsed time: 22.02 	 Loss:35.72839
# Iteration: 84/918000 	 Elapsed time: 22.27 	 Loss:35.67689
# Iteration: 85/918000 	 Elapsed time: 22.59 	 Loss:35.62562
# Iteration: 86/918000 	 Elapsed time: 22.91 	 Loss:35.57464
# Iteration: 87/918000 	 Elapsed time: 23.36 	 Loss:35.52391
# Iteration: 88/918000 	 Elapsed time: 23.56 	 Loss:35.47347
# Iteration: 89/918000 	 Elapsed time: 23.86 	 Loss:35.42326
# Iteration: 90/918000 	 Elapsed time: 24.19 	 Loss:35.37330
# Iteration: 91/918000 	 Elapsed time: 24.51 	 Loss:35.32361
# Iteration: 92/918000 	 Elapsed time: 32.06 	 Loss:35.27414
# Iteration: 93/918000 	 Elapsed time: 32.29 	 Loss:35.22492
# Iteration: 94/918000 	 Elapsed time: 32.48 	 Loss:35.17594
# Iteration: 95/918000 	 Elapsed time: 32.66 	 Loss:35.12716
# Iteration: 96/918000 	 Elapsed time: 32.85 	 Loss:35.07865
# Iteration: 97/918000 	 Elapsed time: 33.00 	 Loss:35.03035
# Iteration: 98/918000 	 Elapsed time: 33.24 	 Loss:34.98225
# Iteration: 99/918000 	 Elapsed time: 33.40 	 Loss:34.93439
# Iteration: 100/918000 	 Elapsed time: 33.59 	 Loss:34.88675
# Iteration: 101/918000 	 Elapsed time: 33.78 	 Loss:34.83932
# Iteration: 102/918000 	 Elapsed time: 33.94 	 Loss:34.79208
# Iteration: 103/918000 	 Elapsed time: 34.35 	 Loss:34.74505
# Iteration: 104/918000 	 Elapsed time: 34.57 	 Loss:34.69824
# Iteration: 105/918000 	 Elapsed time: 34.80 	 Loss:34.65163
# Iteration: 106/918000 	 Elapsed time: 34.98 	 Loss:34.60521
# Iteration: 107/918000 	 Elapsed time: 35.15 	 Loss:34.55898
# Iteration: 108/918000 	 Elapsed time: 35.33 	 Loss:34.51293
# Iteration: 109/918000 	 Elapsed time: 35.52 	 Loss:34.46709
# Iteration: 110/918000 	 Elapsed time: 35.68 	 Loss:34.42143
# Iteration: 111/918000 	 Elapsed time: 36.74 	 Loss:34.37595
# Iteration: 112/918000 	 Elapsed time: 36.93 	 Loss:34.33064
# Iteration: 113/918000 	 Elapsed time: 37.10 	 Loss:34.28551
# Iteration: 114/918000 	 Elapsed time: 37.30 	 Loss:34.24053
# Iteration: 115/918000 	 Elapsed time: 37.48 	 Loss:34.19576
# Iteration: 116/918000 	 Elapsed time: 37.67 	 Loss:34.15113
# Iteration: 117/918000 	 Elapsed time: 37.85 	 Loss:34.10665
# Iteration: 118/918000 	 Elapsed time: 38.03 	 Loss:34.06230
# Iteration: 119/918000 	 Elapsed time: 38.33 	 Loss:34.01812
# Iteration: 120/918000 	 Elapsed time: 38.53 	 Loss:33.97405
# Iteration: 121/918000 	 Elapsed time: 38.70 	 Loss:33.93008
# Iteration: 122/918000 	 Elapsed time: 38.89 	 Loss:33.88621
# Iteration: 123/918000 	 Elapsed time: 39.08 	 Loss:33.84245
# Iteration: 124/918000 	 Elapsed time: 39.29 	 Loss:33.79880
# Iteration: 125/918000 	 Elapsed time: 39.45 	 Loss:33.75532
# Iteration: 126/918000 	 Elapsed time: 39.62 	 Loss:33.71203
# Iteration: 127/918000 	 Elapsed time: 39.81 	 Loss:33.66898
# Iteration: 128/918000 	 Elapsed time: 39.99 	 Loss:33.62608
# Iteration: 129/918000 	 Elapsed time: 40.17 	 Loss:33.58339
# Iteration: 130/918000 	 Elapsed time: 40.65 	 Loss:33.54086
# Iteration: 131/918000 	 Elapsed time: 40.83 	 Loss:33.49849
# Iteration: 132/918000 	 Elapsed time: 40.99 	 Loss:33.45626
# Iteration: 133/918000 	 Elapsed time: 41.15 	 Loss:33.41418
# Iteration: 134/918000 	 Elapsed time: 41.33 	 Loss:33.37223
# Iteration: 135/918000 	 Elapsed time: 41.49 	 Loss:33.33039
# Iteration: 136/918000 	 Elapsed time: 41.66 	 Loss:33.28871
# Iteration: 137/918000 	 Elapsed time: 41.83 	 Loss:33.24715
# Iteration: 138/918000 	 Elapsed time: 42.03 	 Loss:33.20572
# Iteration: 139/918000 	 Elapsed time: 42.21 	 Loss:33.16442
# Iteration: 140/918000 	 Elapsed time: 42.40 	 Loss:33.12325
# Iteration: 141/918000 	 Elapsed time: 42.66 	 Loss:33.08217
# Iteration: 142/918000 	 Elapsed time: 42.83 	 Loss:33.04127
# Iteration: 143/918000 	 Elapsed time: 42.99 	 Loss:33.00046
# Iteration: 144/918000 	 Elapsed time: 43.17 	 Loss:32.95972
# Iteration: 145/918000 	 Elapsed time: 43.35 	 Loss:32.91916
# Iteration: 146/918000 	 Elapsed time: 43.51 	 Loss:32.87872
# Iteration: 147/918000 	 Elapsed time: 43.68 	 Loss:32.83838
# Iteration: 148/918000 	 Elapsed time: 43.84 	 Loss:32.79813
# Iteration: 149/918000 	 Elapsed time: 44.01 	 Loss:32.75804
# Iteration: 150/918000 	 Elapsed time: 44.17 	 Loss:32.71803
# Iteration: 151/918000 	 Elapsed time: 44.34 	 Loss:32.67813
# Iteration: 152/918000 	 Elapsed time: 45.41 	 Loss:32.63836
# Iteration: 153/918000 	 Elapsed time: 45.62 	 Loss:32.59870
# Iteration: 154/918000 	 Elapsed time: 45.81 	 Loss:32.55914
# Iteration: 155/918000 	 Elapsed time: 46.00 	 Loss:32.51968
# Iteration: 156/918000 	 Elapsed time: 46.18 	 Loss:32.48033
# Iteration: 157/918000 	 Elapsed time: 46.36 	 Loss:32.44109
# Iteration: 158/918000 	 Elapsed time: 46.58 	 Loss:32.40196
# Iteration: 159/918000 	 Elapsed time: 46.77 	 Loss:32.36294
# Iteration: 160/918000 	 Elapsed time: 46.93 	 Loss:32.32403
# Iteration: 161/918000 	 Elapsed time: 47.10 	 Loss:32.28524
# Iteration: 162/918000 	 Elapsed time: 47.27 	 Loss:32.24655
# Iteration: 163/918000 	 Elapsed time: 47.46 	 Loss:32.20796
# Iteration: 164/918000 	 Elapsed time: 47.63 	 Loss:32.16946
# Iteration: 165/918000 	 Elapsed time: 47.87 	 Loss:32.13105
# Iteration: 166/918000 	 Elapsed time: 48.07 	 Loss:32.09276
# Iteration: 167/918000 	 Elapsed time: 48.27 	 Loss:32.05459
# Iteration: 168/918000 	 Elapsed time: 48.45 	 Loss:32.01649
# Iteration: 169/918000 	 Elapsed time: 48.91 	 Loss:31.97848
# Iteration: 170/918000 	 Elapsed time: 49.08 	 Loss:31.94058
# Iteration: 171/918000 	 Elapsed time: 49.26 	 Loss:31.90280
# Iteration: 172/918000 	 Elapsed time: 49.44 	 Loss:31.86509
# Iteration: 173/918000 	 Elapsed time: 49.61 	 Loss:31.82748
# Iteration: 174/918000 	 Elapsed time: 49.82 	 Loss:31.78997
# Iteration: 175/918000 	 Elapsed time: 50.44 	 Loss:31.75257
# Iteration: 176/918000 	 Elapsed time: 50.63 	 Loss:31.71522
# Iteration: 177/918000 	 Elapsed time: 50.81 	 Loss:31.67797
# Iteration: 178/918000 	 Elapsed time: 51.00 	 Loss:31.64084
# Iteration: 179/918000 	 Elapsed time: 51.17 	 Loss:31.60378
# Iteration: 180/918000 	 Elapsed time: 51.36 	 Loss:31.56680
# Iteration: 181/918000 	 Elapsed time: 51.97 	 Loss:31.52990
# Iteration: 182/918000 	 Elapsed time: 52.14 	 Loss:31.49311
# Iteration: 183/918000 	 Elapsed time: 52.34 	 Loss:31.45641
# Iteration: 184/918000 	 Elapsed time: 52.64 	 Loss:31.41980
# Iteration: 185/918000 	 Elapsed time: 52.87 	 Loss:31.38326
# Iteration: 186/918000 	 Elapsed time: 53.04 	 Loss:31.34681
# Iteration: 187/918000 	 Elapsed time: 53.26 	 Loss:31.31045
# Iteration: 188/918000 	 Elapsed time: 53.42 	 Loss:31.27417
# Iteration: 189/918000 	 Elapsed time: 53.58 	 Loss:31.23798
# Iteration: 190/918000 	 Elapsed time: 53.74 	 Loss:31.20185
# Iteration: 191/918000 	 Elapsed time: 53.95 	 Loss:31.16580
# Iteration: 192/918000 	 Elapsed time: 54.10 	 Loss:31.12985
# Iteration: 193/918000 	 Elapsed time: 54.26 	 Loss:31.09398
# Iteration: 194/918000 	 Elapsed time: 54.73 	 Loss:31.05818
# Iteration: 195/918000 	 Elapsed time: 54.90 	 Loss:31.02246
# Iteration: 196/918000 	 Elapsed time: 55.09 	 Loss:30.98681
# Iteration: 197/918000 	 Elapsed time: 55.26 	 Loss:30.95124
# Iteration: 198/918000 	 Elapsed time: 55.43 	 Loss:30.91574
# Iteration: 199/918000 	 Elapsed time: 55.61 	 Loss:30.88034
# Iteration: 200/918000 	 Elapsed time: 55.80 	 Loss:30.84499
# Iteration: 201/918000 	 Elapsed time: 56.00 	 Loss:30.80972
# Iteration: 202/918000 	 Elapsed time: 56.17 	 Loss:30.77452
# Iteration: 203/918000 	 Elapsed time: 56.33 	 Loss:30.73940
# Iteration: 204/918000 	 Elapsed time: 56.54 	 Loss:30.70435
# Iteration: 205/918000 	 Elapsed time: 56.72 	 Loss:30.66941
# Iteration: 206/918000 	 Elapsed time: 56.89 	 Loss:30.63455
# Iteration: 207/918000 	 Elapsed time: 57.06 	 Loss:30.59970
# Iteration: 208/918000 	 Elapsed time: 57.23 	 Loss:30.56494
# Iteration: 209/918000 	 Elapsed time: 57.42 	 Loss:30.53032
# Iteration: 210/918000 	 Elapsed time: 57.60 	 Loss:30.49573
# Iteration: 211/918000 	 Elapsed time: 57.79 	 Loss:30.46113
# Iteration: 212/918000 	 Elapsed time: 58.02 	 Loss:30.42665
# Iteration: 213/918000 	 Elapsed time: 58.20 	 Loss:30.39227
# Iteration: 214/918000 	 Elapsed time: 58.37 	 Loss:30.35794
# Iteration: 215/918000 	 Elapsed time: 58.57 	 Loss:30.32369
# Iteration: 216/918000 	 Elapsed time: 58.74 	 Loss:30.28953
# Iteration: 217/918000 	 Elapsed time: 58.92 	 Loss:30.25540
# Iteration: 218/918000 	 Elapsed time: 59.10 	 Loss:30.22135
# Iteration: 219/918000 	 Elapsed time: 59.29 	 Loss:30.18740
# Iteration: 220/918000 	 Elapsed time: 59.49 	 Loss:30.15351
# Iteration: 221/918000 	 Elapsed time: 59.70 	 Loss:30.11965
# Iteration: 222/918000 	 Elapsed time: 59.91 	 Loss:30.08590
# Iteration: 223/918000 	 Elapsed time: 60.07 	 Loss:30.05218
# Iteration: 224/918000 	 Elapsed time: 60.28 	 Loss:30.01855
# Iteration: 225/918000 	 Elapsed time: 60.44 	 Loss:29.98501
# Iteration: 226/918000 	 Elapsed time: 60.60 	 Loss:29.95152
# Iteration: 227/918000 	 Elapsed time: 60.79 	 Loss:29.91808
# Iteration: 228/918000 	 Elapsed time: 60.99 	 Loss:29.88472
# Iteration: 229/918000 	 Elapsed time: 61.16 	 Loss:29.85142
# Iteration: 230/918000 	 Elapsed time: 61.55 	 Loss:29.81819
# Iteration: 231/918000 	 Elapsed time: 61.73 	 Loss:29.78502
# Iteration: 232/918000 	 Elapsed time: 61.90 	 Loss:29.75190
# Iteration: 233/918000 	 Elapsed time: 62.11 	 Loss:29.71883
# Iteration: 234/918000 	 Elapsed time: 62.27 	 Loss:29.68583
# Iteration: 235/918000 	 Elapsed time: 62.42 	 Loss:29.65291
# Iteration: 236/918000 	 Elapsed time: 62.97 	 Loss:29.62005
# Iteration: 237/918000 	 Elapsed time: 63.26 	 Loss:29.58726
# Iteration: 238/918000 	 Elapsed time: 63.43 	 Loss:29.55452
# Iteration: 239/918000 	 Elapsed time: 63.60 	 Loss:29.52184
# Iteration: 240/918000 	 Elapsed time: 63.76 	 Loss:29.48924
# Iteration: 241/918000 	 Elapsed time: 63.99 	 Loss:29.45672
# Iteration: 242/918000 	 Elapsed time: 64.15 	 Loss:29.42422
# Iteration: 243/918000 	 Elapsed time: 64.30 	 Loss:29.39177
# Iteration: 244/918000 	 Elapsed time: 64.48 	 Loss:29.35936
# Iteration: 245/918000 	 Elapsed time: 64.64 	 Loss:29.32704
# Iteration: 246/918000 	 Elapsed time: 64.84 	 Loss:29.29475
# Iteration: 247/918000 	 Elapsed time: 65.00 	 Loss:29.26254
# Iteration: 248/918000 	 Elapsed time: 65.16 	 Loss:29.23038
# Iteration: 249/918000 	 Elapsed time: 65.31 	 Loss:29.19830
# Iteration: 250/918000 	 Elapsed time: 65.47 	 Loss:29.16626
# Iteration: 251/918000 	 Elapsed time: 65.64 	 Loss:29.13426
# Iteration: 252/918000 	 Elapsed time: 65.81 	 Loss:29.10231
# Iteration: 253/918000 	 Elapsed time: 65.97 	 Loss:29.07043
# Iteration: 254/918000 	 Elapsed time: 66.12 	 Loss:29.03861
# Iteration: 255/918000 	 Elapsed time: 66.30 	 Loss:29.00685
# Iteration: 256/918000 	 Elapsed time: 66.48 	 Loss:28.97512
# Iteration: 257/918000 	 Elapsed time: 66.64 	 Loss:28.94348
# Iteration: 258/918000 	 Elapsed time: 66.85 	 Loss:28.91190
# Iteration: 259/918000 	 Elapsed time: 67.00 	 Loss:28.88038
# Iteration: 260/918000 	 Elapsed time: 67.16 	 Loss:28.84889
# Iteration: 261/918000 	 Elapsed time: 67.32 	 Loss:28.81744
# Iteration: 262/918000 	 Elapsed time: 67.48 	 Loss:28.78606
# Iteration: 263/918000 	 Elapsed time: 67.63 	 Loss:28.75473
# Iteration: 264/918000 	 Elapsed time: 67.81 	 Loss:28.72348
# Iteration: 265/918000 	 Elapsed time: 68.01 	 Loss:28.69228
# Iteration: 266/918000 	 Elapsed time: 68.22 	 Loss:28.66112
# Iteration: 267/918000 	 Elapsed time: 68.37 	 Loss:28.63000
# Iteration: 268/918000 	 Elapsed time: 68.55 	 Loss:28.59896
# Iteration: 269/918000 	 Elapsed time: 68.69 	 Loss:28.56799
# Iteration: 270/918000 	 Elapsed time: 68.88 	 Loss:28.53703
# Iteration: 271/918000 	 Elapsed time: 69.11 	 Loss:28.50614
# Iteration: 272/918000 	 Elapsed time: 69.28 	 Loss:28.47524
# Iteration: 273/918000 	 Elapsed time: 69.43 	 Loss:28.44441
# Iteration: 274/918000 	 Elapsed time: 69.67 	 Loss:28.41368
# Iteration: 275/918000 	 Elapsed time: 69.85 	 Loss:28.38300
# Iteration: 276/918000 	 Elapsed time: 70.00 	 Loss:28.35238
# Iteration: 277/918000 	 Elapsed time: 70.15 	 Loss:28.32178
# Iteration: 278/918000 	 Elapsed time: 70.31 	 Loss:28.29119
# Iteration: 279/918000 	 Elapsed time: 70.47 	 Loss:28.26066
# Iteration: 280/918000 	 Elapsed time: 70.62 	 Loss:28.23019
# Iteration: 281/918000 	 Elapsed time: 70.77 	 Loss:28.19979
# Iteration: 282/918000 	 Elapsed time: 70.94 	 Loss:28.16944
# Iteration: 283/918000 	 Elapsed time: 71.10 	 Loss:28.13912
# Iteration: 284/918000 	 Elapsed time: 71.29 	 Loss:28.10884
# Iteration: 285/918000 	 Elapsed time: 71.73 	 Loss:28.07861
# Iteration: 286/918000 	 Elapsed time: 71.93 	 Loss:28.04845
# Iteration: 287/918000 	 Elapsed time: 72.10 	 Loss:28.01833
# Iteration: 288/918000 	 Elapsed time: 72.26 	 Loss:27.98826
# Iteration: 289/918000 	 Elapsed time: 72.43 	 Loss:27.95823
# Iteration: 290/918000 	 Elapsed time: 72.96 	 Loss:27.92823
# Iteration: 291/918000 	 Elapsed time: 73.25 	 Loss:27.89830
# Iteration: 292/918000 	 Elapsed time: 73.47 	 Loss:27.86843
# Iteration: 293/918000 	 Elapsed time: 73.65 	 Loss:27.83860
# Iteration: 294/918000 	 Elapsed time: 73.84 	 Loss:27.80882
# Iteration: 295/918000 	 Elapsed time: 74.12 	 Loss:27.77905
# Iteration: 296/918000 	 Elapsed time: 74.28 	 Loss:27.74933
# Iteration: 297/918000 	 Elapsed time: 74.45 	 Loss:27.71952
# Iteration: 298/918000 	 Elapsed time: 74.65 	 Loss:27.68981
# Iteration: 299/918000 	 Elapsed time: 74.84 	 Loss:27.66025
# Iteration: 300/918000 	 Elapsed time: 75.00 	 Loss:27.63073
# Iteration: 301/918000 	 Elapsed time: 75.17 	 Loss:27.60121
# Iteration: 302/918000 	 Elapsed time: 75.33 	 Loss:27.57172
# Iteration: 303/918000 	 Elapsed time: 75.48 	 Loss:27.54239
# Iteration: 304/918000 	 Elapsed time: 75.65 	 Loss:27.51305
# Iteration: 305/918000 	 Elapsed time: 75.82 	 Loss:27.48366
# Iteration: 306/918000 	 Elapsed time: 75.98 	 Loss:27.45439
# Iteration: 307/918000 	 Elapsed time: 76.16 	 Loss:27.42522
# Iteration: 308/918000 	 Elapsed time: 76.32 	 Loss:27.39601
# Iteration: 309/918000 	 Elapsed time: 76.48 	 Loss:27.36686
# Iteration: 310/918000 	 Elapsed time: 76.65 	 Loss:27.33779
# Iteration: 311/918000 	 Elapsed time: 76.84 	 Loss:27.30874
# Iteration: 312/918000 	 Elapsed time: 77.01 	 Loss:27.27973
# Iteration: 313/918000 	 Elapsed time: 77.18 	 Loss:27.25075
# Iteration: 314/918000 	 Elapsed time: 77.38 	 Loss:27.22184
# Iteration: 315/918000 	 Elapsed time: 77.58 	 Loss:27.19296
# Iteration: 316/918000 	 Elapsed time: 77.75 	 Loss:27.16411
# Iteration: 317/918000 	 Elapsed time: 77.93 	 Loss:27.13533
# Iteration: 318/918000 	 Elapsed time: 78.09 	 Loss:27.10659
# Iteration: 319/918000 	 Elapsed time: 78.27 	 Loss:27.07788
# Iteration: 320/918000 	 Elapsed time: 78.44 	 Loss:27.04921
# Iteration: 321/918000 	 Elapsed time: 78.59 	 Loss:27.02061
# Iteration: 322/918000 	 Elapsed time: 79.07 	 Loss:26.99204
# Iteration: 323/918000 	 Elapsed time: 79.23 	 Loss:26.96350
# Iteration: 324/918000 	 Elapsed time: 79.40 	 Loss:26.93501
# Iteration: 325/918000 	 Elapsed time: 79.55 	 Loss:26.90659
# Iteration: 326/918000 	 Elapsed time: 79.71 	 Loss:26.87813
# Iteration: 327/918000 	 Elapsed time: 79.87 	 Loss:26.84965
# Iteration: 328/918000 	 Elapsed time: 80.05 	 Loss:26.82126
# Iteration: 329/918000 	 Elapsed time: 80.21 	 Loss:26.79300
# Iteration: 330/918000 	 Elapsed time: 80.39 	 Loss:26.76476
# Iteration: 331/918000 	 Elapsed time: 80.57 	 Loss:26.73647
# Iteration: 332/918000 	 Elapsed time: 80.73 	 Loss:26.70826
# Iteration: 333/918000 	 Elapsed time: 80.96 	 Loss:26.68017
# Iteration: 334/918000 	 Elapsed time: 81.16 	 Loss:26.65204
# Iteration: 335/918000 	 Elapsed time: 81.31 	 Loss:26.62393
# Iteration: 336/918000 	 Elapsed time: 81.47 	 Loss:26.59593
# Iteration: 337/918000 	 Elapsed time: 81.63 	 Loss:26.56793
# Iteration: 338/918000 	 Elapsed time: 81.84 	 Loss:26.53995
# Iteration: 339/918000 	 Elapsed time: 82.29 	 Loss:26.51204
# Iteration: 340/918000 	 Elapsed time: 82.47 	 Loss:26.48417
# Iteration: 341/918000 	 Elapsed time: 82.64 	 Loss:26.45631
# Iteration: 342/918000 	 Elapsed time: 82.80 	 Loss:26.42851
# Iteration: 343/918000 	 Elapsed time: 82.95 	 Loss:26.40077
# Iteration: 344/918000 	 Elapsed time: 83.13 	 Loss:26.37304
# Iteration: 345/918000 	 Elapsed time: 83.48 	 Loss:26.34535
# Iteration: 346/918000 	 Elapsed time: 83.82 	 Loss:26.31770
# Iteration: 347/918000 	 Elapsed time: 83.99 	 Loss:26.29010
# Iteration: 348/918000 	 Elapsed time: 84.19 	 Loss:26.26251
# Iteration: 349/918000 	 Elapsed time: 88.44 	 Loss:26.23499
# Iteration: 350/918000 	 Elapsed time: 88.65 	 Loss:26.20750
# Iteration: 351/918000 	 Elapsed time: 88.93 	 Loss:26.18006
# Iteration: 352/918000 	 Elapsed time: 89.10 	 Loss:26.15267
# Iteration: 353/918000 	 Elapsed time: 89.62 	 Loss:26.12536
# Iteration: 354/918000 	 Elapsed time: 89.78 	 Loss:26.09811
# Iteration: 355/918000 	 Elapsed time: 89.99 	 Loss:26.07094
# Iteration: 356/918000 	 Elapsed time: 90.18 	 Loss:26.04365
# Iteration: 357/918000 	 Elapsed time: 90.71 	 Loss:26.01631
# Iteration: 358/918000 	 Elapsed time: 90.91 	 Loss:25.98893
# Iteration: 359/918000 	 Elapsed time: 91.07 	 Loss:25.96170
# Iteration: 360/918000 	 Elapsed time: 91.25 	 Loss:25.93464
# Iteration: 361/918000 	 Elapsed time: 91.40 	 Loss:25.90760
# Iteration: 362/918000 	 Elapsed time: 91.56 	 Loss:25.88053
# Iteration: 363/918000 	 Elapsed time: 91.72 	 Loss:25.85343
# Iteration: 364/918000 	 Elapsed time: 91.97 	 Loss:25.82643
# Iteration: 365/918000 	 Elapsed time: 92.14 	 Loss:25.79952
# Iteration: 366/918000 	 Elapsed time: 92.33 	 Loss:25.77259
# Iteration: 367/918000 	 Elapsed time: 92.49 	 Loss:25.74569
# Iteration: 368/918000 	 Elapsed time: 92.65 	 Loss:25.71885
# Iteration: 369/918000 	 Elapsed time: 92.82 	 Loss:25.69205
# Iteration: 370/918000 	 Elapsed time: 93.01 	 Loss:25.66526
# Iteration: 371/918000 	 Elapsed time: 93.17 	 Loss:25.63851
# Iteration: 372/918000 	 Elapsed time: 93.32 	 Loss:25.61180
# Iteration: 373/918000 	 Elapsed time: 93.49 	 Loss:25.58515
# Iteration: 374/918000 	 Elapsed time: 93.65 	 Loss:25.55853
# Iteration: 375/918000 	 Elapsed time: 93.82 	 Loss:25.53193
# Iteration: 376/918000 	 Elapsed time: 93.99 	 Loss:25.50533
# Iteration: 377/918000 	 Elapsed time: 94.16 	 Loss:25.47881
# Iteration: 378/918000 	 Elapsed time: 94.34 	 Loss:25.45233
# Iteration: 379/918000 	 Elapsed time: 94.50 	 Loss:25.42589
# Iteration: 380/918000 	 Elapsed time: 94.66 	 Loss:25.39947
# Iteration: 381/918000 	 Elapsed time: 94.83 	 Loss:25.37307
# Iteration: 382/918000 	 Elapsed time: 95.02 	 Loss:25.34670
# Iteration: 383/918000 	 Elapsed time: 95.19 	 Loss:25.32038
# Iteration: 384/918000 	 Elapsed time: 95.35 	 Loss:25.29410
# Iteration: 385/918000 	 Elapsed time: 95.52 	 Loss:25.26786
# Iteration: 386/918000 	 Elapsed time: 95.68 	 Loss:25.24165
# Iteration: 387/918000 	 Elapsed time: 95.84 	 Loss:25.21546
# Iteration: 388/918000 	 Elapsed time: 95.99 	 Loss:25.18932
# Iteration: 389/918000 	 Elapsed time: 96.14 	 Loss:25.16320
# Iteration: 390/918000 	 Elapsed time: 96.29 	 Loss:25.13711
# Iteration: 391/918000 	 Elapsed time: 96.44 	 Loss:25.11106
# Iteration: 392/918000 	 Elapsed time: 96.60 	 Loss:25.08506
# Iteration: 393/918000 	 Elapsed time: 96.81 	 Loss:25.05909
# Iteration: 394/918000 	 Elapsed time: 96.98 	 Loss:25.03315
# Iteration: 395/918000 	 Elapsed time: 97.17 	 Loss:25.00723
# Iteration: 396/918000 	 Elapsed time: 97.39 	 Loss:24.98136
# Iteration: 397/918000 	 Elapsed time: 97.60 	 Loss:24.95551
# Iteration: 398/918000 	 Elapsed time: 97.80 	 Loss:24.92970
# Iteration: 399/918000 	 Elapsed time: 98.02 	 Loss:24.90392
# Iteration: 400/918000 	 Elapsed time: 98.21 	 Loss:24.87818
# Iteration: 401/918000 	 Elapsed time: 98.45 	 Loss:24.85247
# Iteration: 402/918000 	 Elapsed time: 98.66 	 Loss:24.82681
# Iteration: 403/918000 	 Elapsed time: 98.86 	 Loss:24.80117
# Iteration: 404/918000 	 Elapsed time: 99.28 	 Loss:24.77557
# Iteration: 405/918000 	 Elapsed time: 99.53 	 Loss:24.75003
# Iteration: 406/918000 	 Elapsed time: 99.71 	 Loss:24.72456
# Iteration: 407/918000 	 Elapsed time: 99.92 	 Loss:24.69913
# Iteration: 408/918000 	 Elapsed time: 100.38 	 Loss:24.67381
# Iteration: 409/918000 	 Elapsed time: 100.57 	 Loss:24.64857
# Iteration: 410/918000 	 Elapsed time: 100.76 	 Loss:24.62325
# Iteration: 411/918000 	 Elapsed time: 100.92 	 Loss:24.59776
# Iteration: 412/918000 	 Elapsed time: 101.08 	 Loss:24.57199
# Iteration: 413/918000 	 Elapsed time: 101.24 	 Loss:24.54652
# Iteration: 414/918000 	 Elapsed time: 101.38 	 Loss:24.52144
# Iteration: 415/918000 	 Elapsed time: 101.53 	 Loss:24.49629
# Iteration: 416/918000 	 Elapsed time: 101.70 	 Loss:24.47096
# Iteration: 417/918000 	 Elapsed time: 101.91 	 Loss:24.44565
# Iteration: 418/918000 	 Elapsed time: 102.13 	 Loss:24.42052
# Iteration: 419/918000 	 Elapsed time: 102.28 	 Loss:24.39540
# Iteration: 420/918000 	 Elapsed time: 102.51 	 Loss:24.37023
# Iteration: 421/918000 	 Elapsed time: 102.67 	 Loss:24.34518
# Iteration: 422/918000 	 Elapsed time: 102.90 	 Loss:24.32019
# Iteration: 423/918000 	 Elapsed time: 103.10 	 Loss:24.29516
# Iteration: 424/918000 	 Elapsed time: 103.34 	 Loss:24.27021
# Iteration: 425/918000 	 Elapsed time: 103.74 	 Loss:24.24526
# Iteration: 426/918000 	 Elapsed time: 103.89 	 Loss:24.22032
# Iteration: 427/918000 	 Elapsed time: 104.03 	 Loss:24.19545
# Iteration: 428/918000 	 Elapsed time: 104.20 	 Loss:24.17060
# Iteration: 429/918000 	 Elapsed time: 104.39 	 Loss:24.14577
# Iteration: 430/918000 	 Elapsed time: 104.94 	 Loss:24.12099
# Iteration: 431/918000 	 Elapsed time: 105.12 	 Loss:24.09626
# Iteration: 432/918000 	 Elapsed time: 105.32 	 Loss:24.07156
# Iteration: 433/918000 	 Elapsed time: 105.52 	 Loss:24.04687
# Iteration: 434/918000 	 Elapsed time: 105.73 	 Loss:24.02222
# Iteration: 435/918000 	 Elapsed time: 106.01 	 Loss:23.99763
# Iteration: 436/918000 	 Elapsed time: 106.22 	 Loss:23.97304
# Iteration: 437/918000 	 Elapsed time: 106.46 	 Loss:23.94847
# Iteration: 438/918000 	 Elapsed time: 106.63 	 Loss:23.92397
# Iteration: 439/918000 	 Elapsed time: 106.81 	 Loss:23.89947
# Iteration: 440/918000 	 Elapsed time: 107.00 	 Loss:23.87496
# Iteration: 441/918000 	 Elapsed time: 107.16 	 Loss:23.85051
# Iteration: 442/918000 	 Elapsed time: 107.33 	 Loss:23.82610
# Iteration: 443/918000 	 Elapsed time: 107.49 	 Loss:23.80170
# Iteration: 444/918000 	 Elapsed time: 107.69 	 Loss:23.77734
# Iteration: 445/918000 	 Elapsed time: 107.89 	 Loss:23.75301
# Iteration: 446/918000 	 Elapsed time: 108.08 	 Loss:23.72876
# Iteration: 447/918000 	 Elapsed time: 108.27 	 Loss:23.70450
# Iteration: 448/918000 	 Elapsed time: 108.47 	 Loss:23.68027
# Iteration: 449/918000 	 Elapsed time: 108.65 	 Loss:23.65608
# Iteration: 450/918000 	 Elapsed time: 108.83 	 Loss:23.63190
# Iteration: 451/918000 	 Elapsed time: 109.01 	 Loss:23.60769
# Iteration: 452/918000 	 Elapsed time: 109.19 	 Loss:23.58348
# Iteration: 453/918000 	 Elapsed time: 109.36 	 Loss:23.55931
# Iteration: 454/918000 	 Elapsed time: 109.53 	 Loss:23.53523
# Iteration: 455/918000 	 Elapsed time: 109.72 	 Loss:23.51115
# Iteration: 456/918000 	 Elapsed time: 109.94 	 Loss:23.48711
# Iteration: 457/918000 	 Elapsed time: 110.20 	 Loss:23.46312
# Iteration: 458/918000 	 Elapsed time: 110.45 	 Loss:23.43918
# Iteration: 459/918000 	 Elapsed time: 110.62 	 Loss:23.41531
# Iteration: 460/918000 	 Elapsed time: 110.84 	 Loss:23.39147
# Iteration: 461/918000 	 Elapsed time: 111.05 	 Loss:23.36766
# Iteration: 462/918000 	 Elapsed time: 111.46 	 Loss:23.34386
# Iteration: 463/918000 	 Elapsed time: 111.70 	 Loss:23.32007
# Iteration: 464/918000 	 Elapsed time: 111.94 	 Loss:23.29629
# Iteration: 465/918000 	 Elapsed time: 112.20 	 Loss:23.27255
# Iteration: 466/918000 	 Elapsed time: 112.47 	 Loss:23.24885
# Iteration: 467/918000 	 Elapsed time: 112.73 	 Loss:23.22519
# Iteration: 468/918000 	 Elapsed time: 112.95 	 Loss:23.20157
# Iteration: 469/918000 	 Elapsed time: 113.20 	 Loss:23.17799
# Iteration: 470/918000 	 Elapsed time: 113.39 	 Loss:23.15443
# Iteration: 471/918000 	 Elapsed time: 113.56 	 Loss:23.13089
# Iteration: 472/918000 	 Elapsed time: 113.72 	 Loss:23.10738
# Iteration: 473/918000 	 Elapsed time: 113.91 	 Loss:23.08388
# Iteration: 474/918000 	 Elapsed time: 114.07 	 Loss:23.06041
# Iteration: 475/918000 	 Elapsed time: 114.23 	 Loss:23.03697
# Iteration: 476/918000 	 Elapsed time: 114.39 	 Loss:23.01356
# Iteration: 477/918000 	 Elapsed time: 114.55 	 Loss:22.99018
# Iteration: 478/918000 	 Elapsed time: 114.77 	 Loss:22.96685
# Iteration: 479/918000 	 Elapsed time: 114.94 	 Loss:22.94354
# Iteration: 480/918000 	 Elapsed time: 115.09 	 Loss:22.92027
# Iteration: 481/918000 	 Elapsed time: 115.27 	 Loss:22.89701
# Iteration: 482/918000 	 Elapsed time: 115.53 	 Loss:22.87380
# Iteration: 483/918000 	 Elapsed time: 115.70 	 Loss:22.85061
# Iteration: 484/918000 	 Elapsed time: 115.88 	 Loss:22.82747
# Iteration: 485/918000 	 Elapsed time: 116.08 	 Loss:22.80436
# Iteration: 486/918000 	 Elapsed time: 116.26 	 Loss:22.78128
# Iteration: 487/918000 	 Elapsed time: 116.44 	 Loss:22.75825
# Iteration: 488/918000 	 Elapsed time: 117.02 	 Loss:22.73522
# Iteration: 489/918000 	 Elapsed time: 117.21 	 Loss:22.71223
# Iteration: 490/918000 	 Elapsed time: 117.49 	 Loss:22.68921
# Iteration: 491/918000 	 Elapsed time: 117.78 	 Loss:22.66624
# Iteration: 492/918000 	 Elapsed time: 117.95 	 Loss:22.64331
# Iteration: 493/918000 	 Elapsed time: 118.13 	 Loss:22.62035
# Iteration: 494/918000 	 Elapsed time: 118.33 	 Loss:22.59740
# Iteration: 495/918000 	 Elapsed time: 118.49 	 Loss:22.57453
# Iteration: 496/918000 	 Elapsed time: 118.65 	 Loss:22.55176
# Iteration: 497/918000 	 Elapsed time: 118.83 	 Loss:22.52900
# Iteration: 498/918000 	 Elapsed time: 119.01 	 Loss:22.50622
# Iteration: 499/918000 	 Elapsed time: 119.23 	 Loss:22.48338
# Iteration: 500/918000 	 Elapsed time: 119.38 	 Loss:22.46063
# Iteration: 501/918000 	 Elapsed time: 119.57 	 Loss:22.43791
# Iteration: 502/918000 	 Elapsed time: 119.76 	 Loss:22.41523
# Iteration: 503/918000 	 Elapsed time: 120.00 	 Loss:22.39257
# Iteration: 504/918000 	 Elapsed time: 120.20 	 Loss:22.36996
# Iteration: 505/918000 	 Elapsed time: 120.37 	 Loss:22.34740
# Iteration: 506/918000 	 Elapsed time: 120.56 	 Loss:22.32481
# Iteration: 507/918000 	 Elapsed time: 120.77 	 Loss:22.30222
# Iteration: 508/918000 	 Elapsed time: 120.96 	 Loss:22.27967
# Iteration: 509/918000 	 Elapsed time: 121.14 	 Loss:22.25722
# Iteration: 510/918000 	 Elapsed time: 121.39 	 Loss:22.23481
# Iteration: 511/918000 	 Elapsed time: 121.95 	 Loss:22.21239
# Iteration: 512/918000 	 Elapsed time: 122.14 	 Loss:22.18995
# Iteration: 513/918000 	 Elapsed time: 122.29 	 Loss:22.16757
# Iteration: 514/918000 	 Elapsed time: 122.46 	 Loss:22.14523
# Iteration: 515/918000 	 Elapsed time: 122.65 	 Loss:22.12293
# Iteration: 516/918000 	 Elapsed time: 122.87 	 Loss:22.10061
# Iteration: 517/918000 	 Elapsed time: 123.24 	 Loss:22.07831
# Iteration: 518/918000 	 Elapsed time: 123.47 	 Loss:22.05606
# Iteration: 519/918000 	 Elapsed time: 123.68 	 Loss:22.03386
# Iteration: 520/918000 	 Elapsed time: 123.86 	 Loss:22.01168
# Iteration: 521/918000 	 Elapsed time: 124.02 	 Loss:21.98951
# Iteration: 522/918000 	 Elapsed time: 124.17 	 Loss:21.96737
# Iteration: 523/918000 	 Elapsed time: 124.33 	 Loss:21.94526
# Iteration: 524/918000 	 Elapsed time: 124.47 	 Loss:21.92318
# Iteration: 525/918000 	 Elapsed time: 124.64 	 Loss:21.90112
# Iteration: 526/918000 	 Elapsed time: 125.21 	 Loss:21.87910
# Iteration: 527/918000 	 Elapsed time: 125.36 	 Loss:21.85712
# Iteration: 528/918000 	 Elapsed time: 125.50 	 Loss:21.83517
# Iteration: 529/918000 	 Elapsed time: 125.65 	 Loss:21.81327
# Iteration: 530/918000 	 Elapsed time: 125.87 	 Loss:21.79140
# Iteration: 531/918000 	 Elapsed time: 126.04 	 Loss:21.76960
# Iteration: 532/918000 	 Elapsed time: 126.23 	 Loss:21.74768
# Iteration: 533/918000 	 Elapsed time: 126.41 	 Loss:21.72576
# Iteration: 534/918000 	 Elapsed time: 126.63 	 Loss:21.70377
# Iteration: 535/918000 	 Elapsed time: 126.81 	 Loss:21.68190
# Iteration: 536/918000 	 Elapsed time: 127.03 	 Loss:21.66015
# Iteration: 537/918000 	 Elapsed time: 127.18 	 Loss:21.63846
# Iteration: 538/918000 	 Elapsed time: 127.33 	 Loss:21.61679
# Iteration: 539/918000 	 Elapsed time: 127.50 	 Loss:21.59503
# Iteration: 540/918000 	 Elapsed time: 127.73 	 Loss:21.57328
# Iteration: 541/918000 	 Elapsed time: 127.92 	 Loss:21.55161
# Iteration: 542/918000 	 Elapsed time: 128.10 	 Loss:21.53003
# Iteration: 543/918000 	 Elapsed time: 128.26 	 Loss:21.50848
# Iteration: 544/918000 	 Elapsed time: 128.42 	 Loss:21.48693
# Iteration: 545/918000 	 Elapsed time: 128.59 	 Loss:21.46542
# Iteration: 546/918000 	 Elapsed time: 128.77 	 Loss:21.44393
# Iteration: 547/918000 	 Elapsed time: 128.93 	 Loss:21.42252
# Iteration: 548/918000 	 Elapsed time: 129.12 	 Loss:21.40100
# Iteration: 549/918000 	 Elapsed time: 129.28 	 Loss:21.37951
# Iteration: 550/918000 	 Elapsed time: 129.43 	 Loss:21.35806
# Iteration: 551/918000 	 Elapsed time: 129.58 	 Loss:21.33664
# Iteration: 552/918000 	 Elapsed time: 129.75 	 Loss:21.31517
# Iteration: 553/918000 	 Elapsed time: 129.97 	 Loss:21.29370
# Iteration: 554/918000 	 Elapsed time: 130.16 	 Loss:21.27237
# Iteration: 555/918000 	 Elapsed time: 130.36 	 Loss:21.25112
# Iteration: 556/918000 	 Elapsed time: 130.56 	 Loss:21.22986
# Iteration: 557/918000 	 Elapsed time: 130.75 	 Loss:21.20855
# Iteration: 558/918000 	 Elapsed time: 130.99 	 Loss:21.18727
# Iteration: 559/918000 	 Elapsed time: 131.18 	 Loss:21.16604
# Iteration: 560/918000 	 Elapsed time: 131.37 	 Loss:21.14486
# Iteration: 561/918000 	 Elapsed time: 131.56 	 Loss:21.12368
# Iteration: 562/918000 	 Elapsed time: 131.73 	 Loss:21.10253
# Iteration: 563/918000 	 Elapsed time: 131.96 	 Loss:21.08141
# Iteration: 564/918000 	 Elapsed time: 132.16 	 Loss:21.06031
# Iteration: 565/918000 	 Elapsed time: 132.37 	 Loss:21.03922
# Iteration: 566/918000 	 Elapsed time: 132.66 	 Loss:21.01815
# Iteration: 567/918000 	 Elapsed time: 132.88 	 Loss:20.99713
# Iteration: 568/918000 	 Elapsed time: 133.05 	 Loss:20.97613
# Iteration: 569/918000 	 Elapsed time: 133.23 	 Loss:20.95514
# Iteration: 570/918000 	 Elapsed time: 133.41 	 Loss:20.93418
# Iteration: 571/918000 	 Elapsed time: 133.60 	 Loss:20.91324
# Iteration: 572/918000 	 Elapsed time: 133.76 	 Loss:20.89231
# Iteration: 573/918000 	 Elapsed time: 133.93 	 Loss:20.87143
# Iteration: 574/918000 	 Elapsed time: 134.10 	 Loss:20.85055
# Iteration: 575/918000 	 Elapsed time: 134.33 	 Loss:20.82971
# Iteration: 576/918000 	 Elapsed time: 134.49 	 Loss:20.80886
# Iteration: 577/918000 	 Elapsed time: 134.67 	 Loss:20.78807
# Iteration: 578/918000 	 Elapsed time: 134.83 	 Loss:20.76729
# Iteration: 579/918000 	 Elapsed time: 135.00 	 Loss:20.74653
# Iteration: 580/918000 	 Elapsed time: 135.17 	 Loss:20.72580
# Iteration: 581/918000 	 Elapsed time: 135.34 	 Loss:20.70510
# Iteration: 582/918000 	 Elapsed time: 135.51 	 Loss:20.68441
# Iteration: 583/918000 	 Elapsed time: 135.70 	 Loss:20.66376
# Iteration: 584/918000 	 Elapsed time: 135.89 	 Loss:20.64312
# Iteration: 585/918000 	 Elapsed time: 136.05 	 Loss:20.62251
# Iteration: 586/918000 	 Elapsed time: 136.20 	 Loss:20.60193
# Iteration: 587/918000 	 Elapsed time: 136.36 	 Loss:20.58139
# Iteration: 588/918000 	 Elapsed time: 136.51 	 Loss:20.56089
# Iteration: 589/918000 	 Elapsed time: 136.66 	 Loss:20.54042
# Iteration: 590/918000 	 Elapsed time: 136.82 	 Loss:20.52001
# Iteration: 591/918000 	 Elapsed time: 137.00 	 Loss:20.49952
# Iteration: 592/918000 	 Elapsed time: 137.19 	 Loss:20.47902
# Iteration: 593/918000 	 Elapsed time: 137.36 	 Loss:20.45841
# Iteration: 594/918000 	 Elapsed time: 137.53 	 Loss:20.43789
# Iteration: 595/918000 	 Elapsed time: 137.70 	 Loss:20.41749
# Iteration: 596/918000 	 Elapsed time: 137.86 	 Loss:20.39719
# Iteration: 597/918000 	 Elapsed time: 138.02 	 Loss:20.37690
# Iteration: 598/918000 	 Elapsed time: 138.26 	 Loss:20.35655
# Iteration: 599/918000 	 Elapsed time: 138.42 	 Loss:20.33618
# Iteration: 600/918000 	 Elapsed time: 138.59 	 Loss:20.31585
# Iteration: 601/918000 	 Elapsed time: 138.75 	 Loss:20.29563
# Iteration: 602/918000 	 Elapsed time: 138.97 	 Loss:20.27546
# Iteration: 603/918000 	 Elapsed time: 139.15 	 Loss:20.25525
# Iteration: 604/918000 	 Elapsed time: 139.31 	 Loss:20.23500
# Iteration: 605/918000 	 Elapsed time: 139.47 	 Loss:20.21478
# Iteration: 606/918000 	 Elapsed time: 139.64 	 Loss:20.19461
# Iteration: 607/918000 	 Elapsed time: 139.79 	 Loss:20.17455
# Iteration: 608/918000 	 Elapsed time: 139.94 	 Loss:20.15456
# Iteration: 609/918000 	 Elapsed time: 140.09 	 Loss:20.13456
# Iteration: 610/918000 	 Elapsed time: 140.26 	 Loss:20.11441
# Iteration: 611/918000 	 Elapsed time: 140.42 	 Loss:20.09411
# Iteration: 612/918000 	 Elapsed time: 140.90 	 Loss:20.07393
# Iteration: 613/918000 	 Elapsed time: 141.07 	 Loss:20.05401
# Iteration: 614/918000 	 Elapsed time: 141.25 	 Loss:20.03414
# Iteration: 615/918000 	 Elapsed time: 141.41 	 Loss:20.01407
# Iteration: 616/918000 	 Elapsed time: 141.62 	 Loss:19.99399
# Iteration: 617/918000 	 Elapsed time: 141.78 	 Loss:19.97408
# Iteration: 618/918000 	 Elapsed time: 141.97 	 Loss:19.95424
# Iteration: 619/918000 	 Elapsed time: 142.13 	 Loss:19.93429
# Iteration: 620/918000 	 Elapsed time: 142.34 	 Loss:19.91436
# Iteration: 621/918000 	 Elapsed time: 142.50 	 Loss:19.89454
# Iteration: 622/918000 	 Elapsed time: 142.77 	 Loss:19.87472
# Iteration: 623/918000 	 Elapsed time: 142.95 	 Loss:19.85484
# Iteration: 624/918000 	 Elapsed time: 143.10 	 Loss:19.83501
# Iteration: 625/918000 	 Elapsed time: 143.26 	 Loss:19.81528
# Iteration: 626/918000 	 Elapsed time: 143.41 	 Loss:19.79555
# Iteration: 627/918000 	 Elapsed time: 143.79 	 Loss:19.77577
# Iteration: 628/918000 	 Elapsed time: 143.94 	 Loss:19.75604
# Iteration: 629/918000 	 Elapsed time: 144.08 	 Loss:19.73635
# Iteration: 630/918000 	 Elapsed time: 144.42 	 Loss:19.71667
# Iteration: 631/918000 	 Elapsed time: 144.59 	 Loss:19.69700
# Iteration: 632/918000 	 Elapsed time: 144.75 	 Loss:19.67738
# Iteration: 633/918000 	 Elapsed time: 144.92 	 Loss:19.65777
# Iteration: 634/918000 	 Elapsed time: 145.10 	 Loss:19.63815
# Iteration: 635/918000 	 Elapsed time: 145.26 	 Loss:19.61855
# Iteration: 636/918000 	 Elapsed time: 145.41 	 Loss:19.59900
# Iteration: 637/918000 	 Elapsed time: 145.56 	 Loss:19.57947
# Iteration: 638/918000 	 Elapsed time: 145.72 	 Loss:19.55994
# Iteration: 639/918000 	 Elapsed time: 145.87 	 Loss:19.54044
# Iteration: 640/918000 	 Elapsed time: 146.02 	 Loss:19.52097
# Iteration: 641/918000 	 Elapsed time: 146.17 	 Loss:19.50150
# Iteration: 642/918000 	 Elapsed time: 146.32 	 Loss:19.48203
# Iteration: 643/918000 	 Elapsed time: 146.47 	 Loss:19.46262
# Iteration: 644/918000 	 Elapsed time: 146.63 	 Loss:19.44321
# Iteration: 645/918000 	 Elapsed time: 146.77 	 Loss:19.42382
# Iteration: 646/918000 	 Elapsed time: 146.94 	 Loss:19.40446
# Iteration: 647/918000 	 Elapsed time: 147.10 	 Loss:19.38511
# Iteration: 648/918000 	 Elapsed time: 147.26 	 Loss:19.36578
# Iteration: 649/918000 	 Elapsed time: 147.43 	 Loss:19.34645
# Iteration: 650/918000 	 Elapsed time: 147.60 	 Loss:19.32717
# Iteration: 651/918000 	 Elapsed time: 147.76 	 Loss:19.30788
# Iteration: 652/918000 	 Elapsed time: 147.90 	 Loss:19.28864
# Iteration: 653/918000 	 Elapsed time: 148.05 	 Loss:19.26941
# Iteration: 654/918000 	 Elapsed time: 148.22 	 Loss:19.25020
# Iteration: 655/918000 	 Elapsed time: 148.39 	 Loss:19.23100
# Iteration: 656/918000 	 Elapsed time: 148.55 	 Loss:19.21185
# Iteration: 657/918000 	 Elapsed time: 148.70 	 Loss:19.19273
# Iteration: 658/918000 	 Elapsed time: 148.84 	 Loss:19.17366
# Iteration: 659/918000 	 Elapsed time: 149.00 	 Loss:19.15466
# Iteration: 660/918000 	 Elapsed time: 149.17 	 Loss:19.13578
# Iteration: 661/918000 	 Elapsed time: 149.32 	 Loss:19.11679
# Iteration: 662/918000 	 Elapsed time: 149.47 	 Loss:19.09774
# Iteration: 663/918000 	 Elapsed time: 149.61 	 Loss:19.07842
# Iteration: 664/918000 	 Elapsed time: 149.77 	 Loss:19.05925
# Iteration: 665/918000 	 Elapsed time: 149.92 	 Loss:19.04033
# Iteration: 666/918000 	 Elapsed time: 150.07 	 Loss:19.02150
# Iteration: 667/918000 	 Elapsed time: 150.21 	 Loss:19.00245
# Iteration: 668/918000 	 Elapsed time: 150.36 	 Loss:18.98337
# Iteration: 669/918000 	 Elapsed time: 150.53 	 Loss:18.96437
# Iteration: 670/918000 	 Elapsed time: 150.68 	 Loss:18.94544
# Iteration: 671/918000 	 Elapsed time: 150.84 	 Loss:18.92638
# Iteration: 672/918000 	 Elapsed time: 151.01 	 Loss:18.90742
# Iteration: 673/918000 	 Elapsed time: 151.19 	 Loss:18.88867
# Iteration: 674/918000 	 Elapsed time: 151.39 	 Loss:18.86989
# Iteration: 675/918000 	 Elapsed time: 151.55 	 Loss:18.85096
# Iteration: 676/918000 	 Elapsed time: 151.72 	 Loss:18.83203
# Iteration: 677/918000 	 Elapsed time: 151.87 	 Loss:18.81325
# Iteration: 678/918000 	 Elapsed time: 152.07 	 Loss:18.79451
# Iteration: 679/918000 	 Elapsed time: 152.23 	 Loss:18.77571
# Iteration: 680/918000 	 Elapsed time: 152.38 	 Loss:18.75697
# Iteration: 681/918000 	 Elapsed time: 152.68 	 Loss:18.73826
# Iteration: 682/918000 	 Elapsed time: 152.86 	 Loss:18.71950
# Iteration: 683/918000 	 Elapsed time: 153.06 	 Loss:18.70076
# Iteration: 684/918000 	 Elapsed time: 153.25 	 Loss:18.68209
# Iteration: 685/918000 	 Elapsed time: 153.40 	 Loss:18.66346
# Iteration: 686/918000 	 Elapsed time: 153.58 	 Loss:18.64481
# Iteration: 687/918000 	 Elapsed time: 153.75 	 Loss:18.62617
# Iteration: 688/918000 	 Elapsed time: 153.90 	 Loss:18.60755
# Iteration: 689/918000 	 Elapsed time: 154.05 	 Loss:18.58895
# Iteration: 690/918000 	 Elapsed time: 154.20 	 Loss:18.57036
# Iteration: 691/918000 	 Elapsed time: 154.35 	 Loss:18.55181
# Iteration: 692/918000 	 Elapsed time: 154.54 	 Loss:18.53327
# Iteration: 693/918000 	 Elapsed time: 154.72 	 Loss:18.51472
# Iteration: 694/918000 	 Elapsed time: 155.22 	 Loss:18.49621
# Iteration: 695/918000 	 Elapsed time: 155.42 	 Loss:18.47772
# Iteration: 696/918000 	 Elapsed time: 155.57 	 Loss:18.45923
# Iteration: 697/918000 	 Elapsed time: 155.73 	 Loss:18.44078
# Iteration: 698/918000 	 Elapsed time: 155.89 	 Loss:18.42233
# Iteration: 699/918000 	 Elapsed time: 156.05 	 Loss:18.40391
# Iteration: 700/918000 	 Elapsed time: 156.21 	 Loss:18.38548
# Iteration: 701/918000 	 Elapsed time: 156.36 	 Loss:18.36709
# Iteration: 702/918000 	 Elapsed time: 156.53 	 Loss:18.34872
# Iteration: 703/918000 	 Elapsed time: 156.67 	 Loss:18.33033
# Iteration: 704/918000 	 Elapsed time: 156.82 	 Loss:18.31200
# Iteration: 705/918000 	 Elapsed time: 156.98 	 Loss:18.29366
# Iteration: 706/918000 	 Elapsed time: 157.16 	 Loss:18.27537
# Iteration: 707/918000 	 Elapsed time: 157.38 	 Loss:18.25707
# Iteration: 708/918000 	 Elapsed time: 157.55 	 Loss:18.23880
# Iteration: 709/918000 	 Elapsed time: 157.73 	 Loss:18.22053
# Iteration: 710/918000 	 Elapsed time: 157.88 	 Loss:18.20227
# Iteration: 711/918000 	 Elapsed time: 158.03 	 Loss:18.18404
# Iteration: 712/918000 	 Elapsed time: 158.17 	 Loss:18.16584
# Iteration: 713/918000 	 Elapsed time: 158.64 	 Loss:18.14763
# Iteration: 714/918000 	 Elapsed time: 158.79 	 Loss:18.12945
# Iteration: 715/918000 	 Elapsed time: 158.95 	 Loss:18.11127
# Iteration: 716/918000 	 Elapsed time: 159.12 	 Loss:18.09314
# Iteration: 717/918000 	 Elapsed time: 159.27 	 Loss:18.07500
# Iteration: 718/918000 	 Elapsed time: 159.42 	 Loss:18.05688
# Iteration: 719/918000 	 Elapsed time: 159.57 	 Loss:18.03878
# Iteration: 720/918000 	 Elapsed time: 159.73 	 Loss:18.02068
# Iteration: 721/918000 	 Elapsed time: 159.91 	 Loss:18.00261
# Iteration: 722/918000 	 Elapsed time: 160.06 	 Loss:17.98456
# Iteration: 723/918000 	 Elapsed time: 160.21 	 Loss:17.96652
# Iteration: 724/918000 	 Elapsed time: 160.36 	 Loss:17.94850
# Iteration: 725/918000 	 Elapsed time: 160.84 	 Loss:17.93049
# Iteration: 726/918000 	 Elapsed time: 161.01 	 Loss:17.91251
# Iteration: 727/918000 	 Elapsed time: 161.16 	 Loss:17.89453
# Iteration: 728/918000 	 Elapsed time: 161.31 	 Loss:17.87658
# Iteration: 729/918000 	 Elapsed time: 161.46 	 Loss:17.85864
# Iteration: 730/918000 	 Elapsed time: 161.60 	 Loss:17.84074
# Iteration: 731/918000 	 Elapsed time: 161.76 	 Loss:17.82286
# Iteration: 732/918000 	 Elapsed time: 161.93 	 Loss:17.80503
# Iteration: 733/918000 	 Elapsed time: 162.08 	 Loss:17.78724
# Iteration: 734/918000 	 Elapsed time: 162.25 	 Loss:17.76951
# Iteration: 735/918000 	 Elapsed time: 162.41 	 Loss:17.75162
# Iteration: 736/918000 	 Elapsed time: 162.64 	 Loss:17.73372
# Iteration: 737/918000 	 Elapsed time: 162.87 	 Loss:17.71576
# Iteration: 738/918000 	 Elapsed time: 163.02 	 Loss:17.69786
# Iteration: 739/918000 	 Elapsed time: 163.17 	 Loss:17.68010
# Iteration: 740/918000 	 Elapsed time: 163.33 	 Loss:17.66232
# Iteration: 741/918000 	 Elapsed time: 163.51 	 Loss:17.64456
# Iteration: 742/918000 	 Elapsed time: 163.66 	 Loss:17.62681
# Iteration: 743/918000 	 Elapsed time: 164.00 	 Loss:17.60908
# Iteration: 744/918000 	 Elapsed time: 164.16 	 Loss:17.59139
# Iteration: 745/918000 	 Elapsed time: 164.31 	 Loss:17.57369
# Iteration: 746/918000 	 Elapsed time: 164.45 	 Loss:17.55602
# Iteration: 747/918000 	 Elapsed time: 164.66 	 Loss:17.53836
# Iteration: 748/918000 	 Elapsed time: 164.81 	 Loss:17.52074
# Iteration: 749/918000 	 Elapsed time: 164.97 	 Loss:17.50311
# Iteration: 750/918000 	 Elapsed time: 165.13 	 Loss:17.48550
# Iteration: 751/918000 	 Elapsed time: 165.28 	 Loss:17.46783
# Iteration: 752/918000 	 Elapsed time: 165.43 	 Loss:17.45015
# Iteration: 753/918000 	 Elapsed time: 165.59 	 Loss:17.43250
# Iteration: 754/918000 	 Elapsed time: 165.76 	 Loss:17.41492
# Iteration: 755/918000 	 Elapsed time: 165.94 	 Loss:17.39740
# Iteration: 756/918000 	 Elapsed time: 166.09 	 Loss:17.37992
# Iteration: 757/918000 	 Elapsed time: 166.36 	 Loss:17.36241
# Iteration: 758/918000 	 Elapsed time: 166.54 	 Loss:17.34487
# Iteration: 759/918000 	 Elapsed time: 167.13 	 Loss:17.32734
# Iteration: 760/918000 	 Elapsed time: 167.31 	 Loss:17.30985
# Iteration: 761/918000 	 Elapsed time: 167.48 	 Loss:17.29238
# Iteration: 762/918000 	 Elapsed time: 167.72 	 Loss:17.27493
# Iteration: 763/918000 	 Elapsed time: 167.93 	 Loss:17.25750
# Iteration: 764/918000 	 Elapsed time: 168.11 	 Loss:17.24009
# Iteration: 765/918000 	 Elapsed time: 168.29 	 Loss:17.22267
# Iteration: 766/918000 	 Elapsed time: 168.46 	 Loss:17.20527
# Iteration: 767/918000 	 Elapsed time: 168.64 	 Loss:17.18787
# Iteration: 768/918000 	 Elapsed time: 168.81 	 Loss:17.17050
# Iteration: 769/918000 	 Elapsed time: 169.04 	 Loss:17.15314
# Iteration: 770/918000 	 Elapsed time: 169.22 	 Loss:17.13585
# Iteration: 771/918000 	 Elapsed time: 169.40 	 Loss:17.11854
# Iteration: 772/918000 	 Elapsed time: 169.58 	 Loss:17.10125
# Iteration: 773/918000 	 Elapsed time: 169.74 	 Loss:17.08394
# Iteration: 774/918000 	 Elapsed time: 169.90 	 Loss:17.06663
# Iteration: 775/918000 	 Elapsed time: 170.08 	 Loss:17.04935
# Iteration: 776/918000 	 Elapsed time: 170.26 	 Loss:17.03211
# Iteration: 777/918000 	 Elapsed time: 170.44 	 Loss:17.01490
# Iteration: 778/918000 	 Elapsed time: 170.60 	 Loss:16.99767
# Iteration: 779/918000 	 Elapsed time: 170.77 	 Loss:16.98046
# Iteration: 780/918000 	 Elapsed time: 170.92 	 Loss:16.96328
# Iteration: 781/918000 	 Elapsed time: 171.08 	 Loss:16.94612
# Iteration: 782/918000 	 Elapsed time: 171.23 	 Loss:16.92898
# Iteration: 783/918000 	 Elapsed time: 171.38 	 Loss:16.91187
# Iteration: 784/918000 	 Elapsed time: 171.54 	 Loss:16.89482
# Iteration: 785/918000 	 Elapsed time: 171.70 	 Loss:16.87773
# Iteration: 786/918000 	 Elapsed time: 172.22 	 Loss:16.86066
# Iteration: 787/918000 	 Elapsed time: 172.36 	 Loss:16.84345
# Iteration: 788/918000 	 Elapsed time: 172.54 	 Loss:16.82628
# Iteration: 789/918000 	 Elapsed time: 172.78 	 Loss:16.80913
# Iteration: 790/918000 	 Elapsed time: 173.01 	 Loss:16.79206
# Iteration: 791/918000 	 Elapsed time: 173.23 	 Loss:16.77502
# Iteration: 792/918000 	 Elapsed time: 173.37 	 Loss:16.75800
# Iteration: 793/918000 	 Elapsed time: 173.83 	 Loss:16.74100
# ...
# Iteration: 96574/918000 	 Elapsed time: 22612.75 	 Loss:-7.43756
# Iteration: 96575/918000 	 Elapsed time: 22612.91 	 Loss:-8.82093
# Iteration: 96576/918000 	 Elapsed time: 22613.10 	 Loss:-8.80367
# Iteration: 96577/918000 	 Elapsed time: 22613.25 	 Loss:-8.16171
# Iteration: 96578/918000 	 Elapsed time: 22613.42 	 Loss:-4.30805
# Iteration: 96579/918000 	 Elapsed time: 22613.56 	 Loss:-8.58057
# Iteration: 96580/918000 	 Elapsed time: 22613.73 	 Loss:-8.66692
# Iteration: 96581/918000 	 Elapsed time: 22614.32 	 Loss:-8.33988
# Iteration: 96582/918000 	 Elapsed time: 22614.48 	 Loss:-8.78083
# Iteration: 96583/918000 	 Elapsed time: 22614.64 	 Loss:-8.87111
# Iteration: 96584/918000 	 Elapsed time: 22614.80 	 Loss:-8.84451
# Iteration: 96585/918000 	 Elapsed time: 22614.94 	 Loss:1.33311
# Iteration: 96586/918000 	 Elapsed time: 22615.10 	 Loss:-8.87649
# Iteration: 96587/918000 	 Elapsed time: 22615.24 	 Loss:-8.91613
# Iteration: 96588/918000 	 Elapsed time: 22615.39 	 Loss:-8.83992
# Iteration: 96589/918000 	 Elapsed time: 22615.54 	 Loss:-8.87814
# Iteration: 96590/918000 	 Elapsed time: 22615.69 	 Loss:-8.94139
# Iteration: 96591/918000 	 Elapsed time: 22615.84 	 Loss:-8.93083
# Iteration: 96592/918000 	 Elapsed time: 22616.00 	 Loss:-8.92429
# Iteration: 96593/918000 	 Elapsed time: 22616.15 	 Loss:-8.90740
# Iteration: 96594/918000 	 Elapsed time: 22616.30 	 Loss:-6.84499
# Iteration: 96595/918000 	 Elapsed time: 22616.46 	 Loss:-8.90756
# Iteration: 96596/918000 	 Elapsed time: 22616.61 	 Loss:3.72791
# Iteration: 96597/918000 	 Elapsed time: 22616.77 	 Loss:-8.81062
# Iteration: 96598/918000 	 Elapsed time: 22616.93 	 Loss:-8.78817
# Iteration: 96599/918000 	 Elapsed time: 22617.09 	 Loss:-5.12128
# Iteration: 96600/918000 	 Elapsed time: 22617.28 	 Loss:-3.39813
# Iteration: 96601/918000 	 Elapsed time: 22617.43 	 Loss:-8.74595
# Iteration: 96602/918000 	 Elapsed time: 22617.59 	 Loss:-8.72333
# Iteration: 96603/918000 	 Elapsed time: 22617.78 	 Loss:-8.88739
# Iteration: 96604/918000 	 Elapsed time: 22617.95 	 Loss:-8.87994
# Iteration: 96605/918000 	 Elapsed time: 22618.10 	 Loss:-8.83046
# Iteration: 96606/918000 	 Elapsed time: 22618.28 	 Loss:-8.81704
# Iteration: 96607/918000 	 Elapsed time: 22618.43 	 Loss:-8.90166
# Iteration: 96608/918000 	 Elapsed time: 22618.57 	 Loss:-8.86170
# Iteration: 96609/918000 	 Elapsed time: 22618.73 	 Loss:-5.86158
# Iteration: 96610/918000 	 Elapsed time: 22618.90 	 Loss:-7.89166
# Iteration: 96611/918000 	 Elapsed time: 22619.04 	 Loss:-8.71922
# Iteration: 96612/918000 	 Elapsed time: 22619.21 	 Loss:-8.92262
# Iteration: 96613/918000 	 Elapsed time: 22619.37 	 Loss:-8.75981
# Iteration: 96614/918000 	 Elapsed time: 22619.52 	 Loss:-8.63253
# Iteration: 96615/918000 	 Elapsed time: 22619.68 	 Loss:-3.67051
# Iteration: 96616/918000 	 Elapsed time: 22619.83 	 Loss:18.24800
# Iteration: 96617/918000 	 Elapsed time: 22620.00 	 Loss:-8.35159
# Iteration: 96618/918000 	 Elapsed time: 22620.18 	 Loss:-8.35694
# Iteration: 96619/918000 	 Elapsed time: 22620.32 	 Loss:-8.76764
# Iteration: 96620/918000 	 Elapsed time: 22620.50 	 Loss:-8.78351
# Iteration: 96621/918000 	 Elapsed time: 22620.64 	 Loss:12.72681
# Iteration: 96622/918000 	 Elapsed time: 22620.79 	 Loss:-8.36516
# Iteration: 96623/918000 	 Elapsed time: 22620.94 	 Loss:-8.68917
# Iteration: 96624/918000 	 Elapsed time: 22621.09 	 Loss:-7.84917
# Iteration: 96625/918000 	 Elapsed time: 22621.24 	 Loss:-8.65383
# Iteration: 96626/918000 	 Elapsed time: 22621.40 	 Loss:-8.74948
# Iteration: 96627/918000 	 Elapsed time: 22621.55 	 Loss:-8.91240
# Iteration: 96628/918000 	 Elapsed time: 22621.73 	 Loss:-8.79305
# Iteration: 96629/918000 	 Elapsed time: 22621.88 	 Loss:-8.84771
# Iteration: 96630/918000 	 Elapsed time: 22622.03 	 Loss:-8.88490
# Iteration: 96631/918000 	 Elapsed time: 22622.18 	 Loss:-8.84328
# Iteration: 96632/918000 	 Elapsed time: 22622.34 	 Loss:-8.88136
# Iteration: 96633/918000 	 Elapsed time: 22622.60 	 Loss:-8.87236
# Iteration: 96634/918000 	 Elapsed time: 22622.77 	 Loss:1.70405
# Iteration: 96635/918000 	 Elapsed time: 22622.91 	 Loss:-8.56282
# Iteration: 96636/918000 	 Elapsed time: 22623.06 	 Loss:-8.65224
# Iteration: 96637/918000 	 Elapsed time: 22623.23 	 Loss:-0.72352
# Iteration: 96638/918000 	 Elapsed time: 22623.37 	 Loss:-8.87144
# Iteration: 96639/918000 	 Elapsed time: 22623.52 	 Loss:-8.84680
# Iteration: 96640/918000 	 Elapsed time: 22623.67 	 Loss:-8.84562
# Iteration: 96641/918000 	 Elapsed time: 22623.82 	 Loss:-8.85282
# Iteration: 96642/918000 	 Elapsed time: 22623.98 	 Loss:-8.86591
# Iteration: 96643/918000 	 Elapsed time: 22624.14 	 Loss:-8.87728
# Iteration: 96644/918000 	 Elapsed time: 22624.29 	 Loss:-8.85951
# Iteration: 96645/918000 	 Elapsed time: 22624.45 	 Loss:-8.89804
# Iteration: 96646/918000 	 Elapsed time: 22624.63 	 Loss:-0.29579
# Iteration: 96647/918000 	 Elapsed time: 22624.78 	 Loss:-8.82729
# Iteration: 96648/918000 	 Elapsed time: 22624.94 	 Loss:-8.88442
# Iteration: 96649/918000 	 Elapsed time: 22625.12 	 Loss:-8.85167
# Iteration: 96650/918000 	 Elapsed time: 22625.27 	 Loss:-7.59945
# Iteration: 96651/918000 	 Elapsed time: 22625.51 	 Loss:-8.86443
# Iteration: 96652/918000 	 Elapsed time: 22625.65 	 Loss:-8.88392
# Iteration: 96653/918000 	 Elapsed time: 22625.83 	 Loss:2.95539
# Iteration: 96654/918000 	 Elapsed time: 22625.98 	 Loss:-8.68951
# Iteration: 96655/918000 	 Elapsed time: 22626.15 	 Loss:-8.68860
# Iteration: 96656/918000 	 Elapsed time: 22626.30 	 Loss:-8.80940
# Iteration: 96657/918000 	 Elapsed time: 22626.47 	 Loss:-8.77938
# Iteration: 96658/918000 	 Elapsed time: 22626.64 	 Loss:-8.72194
# Iteration: 96659/918000 	 Elapsed time: 22626.79 	 Loss:-8.63742
# Iteration: 96660/918000 	 Elapsed time: 22626.94 	 Loss:-8.80711
# Iteration: 96661/918000 	 Elapsed time: 22627.10 	 Loss:-8.72219
# Iteration: 96662/918000 	 Elapsed time: 22627.27 	 Loss:-8.87455
# Iteration: 96663/918000 	 Elapsed time: 22627.42 	 Loss:-8.83739
# Iteration: 96664/918000 	 Elapsed time: 22627.59 	 Loss:-8.73868
# Iteration: 96665/918000 	 Elapsed time: 22627.79 	 Loss:-8.89227
# Iteration: 96666/918000 	 Elapsed time: 22627.93 	 Loss:-8.83389
# Iteration: 96667/918000 	 Elapsed time: 22628.08 	 Loss:-7.14360
# Iteration: 96668/918000 	 Elapsed time: 22628.26 	 Loss:-8.86284
# Iteration: 96669/918000 	 Elapsed time: 22628.43 	 Loss:-8.86387
# Iteration: 96670/918000 	 Elapsed time: 22629.05 	 Loss:-8.89008
# Iteration: 96671/918000 	 Elapsed time: 22629.20 	 Loss:-8.93884
# Iteration: 96672/918000 	 Elapsed time: 22629.37 	 Loss:-8.92404
# Iteration: 96673/918000 	 Elapsed time: 22629.55 	 Loss:-8.29018
# Iteration: 96674/918000 	 Elapsed time: 22629.72 	 Loss:-8.87076
# Iteration: 96675/918000 	 Elapsed time: 22629.86 	 Loss:-8.86136
# Iteration: 96676/918000 	 Elapsed time: 22630.03 	 Loss:-8.42361
# Iteration: 96677/918000 	 Elapsed time: 22630.18 	 Loss:-8.88730
# Iteration: 96678/918000 	 Elapsed time: 22630.33 	 Loss:-8.93139
# Iteration: 96679/918000 	 Elapsed time: 22630.48 	 Loss:-8.85869
# Iteration: 96680/918000 	 Elapsed time: 22630.63 	 Loss:-8.92145
# Iteration: 96681/918000 	 Elapsed time: 22630.82 	 Loss:-8.82569
# Iteration: 96682/918000 	 Elapsed time: 22630.96 	 Loss:-8.91971
# Iteration: 96683/918000 	 Elapsed time: 22631.11 	 Loss:-8.90828
# Iteration: 96684/918000 	 Elapsed time: 22631.32 	 Loss:-8.90164
# Iteration: 96685/918000 	 Elapsed time: 22631.49 	 Loss:-8.91140
# Iteration: 96686/918000 	 Elapsed time: 22631.64 	 Loss:-8.92898
# Iteration: 96687/918000 	 Elapsed time: 22631.83 	 Loss:-8.95279
# Iteration: 96688/918000 	 Elapsed time: 22632.01 	 Loss:-8.94407
# Iteration: 96689/918000 	 Elapsed time: 22632.15 	 Loss:-8.58904
# Iteration: 96690/918000 	 Elapsed time: 22632.32 	 Loss:-8.92828
# Iteration: 96691/918000 	 Elapsed time: 22632.51 	 Loss:-8.93966
# Iteration: 96692/918000 	 Elapsed time: 22632.67 	 Loss:-8.94471
# Iteration: 96693/918000 	 Elapsed time: 22632.83 	 Loss:22.77081
# Iteration: 96694/918000 	 Elapsed time: 22633.02 	 Loss:-8.86380
# Iteration: 96695/918000 	 Elapsed time: 22633.17 	 Loss:-8.85297
# Iteration: 96696/918000 	 Elapsed time: 22633.35 	 Loss:-8.92961
# Iteration: 96697/918000 	 Elapsed time: 22633.50 	 Loss:-8.85974
# Iteration: 96698/918000 	 Elapsed time: 22633.65 	 Loss:-8.65458
# Iteration: 96699/918000 	 Elapsed time: 22633.85 	 Loss:-1.08602
# Iteration: 96700/918000 	 Elapsed time: 22634.01 	 Loss:-8.81119
# Iteration: 96701/918000 	 Elapsed time: 22634.18 	 Loss:-8.84597
# Iteration: 96702/918000 	 Elapsed time: 22634.39 	 Loss:-8.78660
# Iteration: 96703/918000 	 Elapsed time: 22634.54 	 Loss:-8.87257
# Iteration: 96704/918000 	 Elapsed time: 22634.69 	 Loss:-8.84709
# Iteration: 96705/918000 	 Elapsed time: 22634.85 	 Loss:-8.85216
# Iteration: 96706/918000 	 Elapsed time: 22635.00 	 Loss:-8.91036
# Iteration: 96707/918000 	 Elapsed time: 22635.15 	 Loss:-8.88414
# Iteration: 96708/918000 	 Elapsed time: 22635.31 	 Loss:-8.97101
# Iteration: 96709/918000 	 Elapsed time: 22635.46 	 Loss:-8.90471
# Iteration: 96710/918000 	 Elapsed time: 22635.61 	 Loss:-8.94848
# Iteration: 96711/918000 	 Elapsed time: 22635.77 	 Loss:-8.92638
# Iteration: 96712/918000 	 Elapsed time: 22635.93 	 Loss:-8.85253
# Iteration: 96713/918000 	 Elapsed time: 22636.09 	 Loss:-8.95206
# Iteration: 96714/918000 	 Elapsed time: 22636.24 	 Loss:-8.92408
# Iteration: 96715/918000 	 Elapsed time: 22636.42 	 Loss:-8.97853
# Iteration: 96716/918000 	 Elapsed time: 22636.57 	 Loss:-7.87080
# Iteration: 96717/918000 	 Elapsed time: 22636.71 	 Loss:-8.92254
# Iteration: 96718/918000 	 Elapsed time: 22636.85 	 Loss:-8.93669
# Iteration: 96719/918000 	 Elapsed time: 22637.02 	 Loss:-8.92523
# Iteration: 96720/918000 	 Elapsed time: 22637.19 	 Loss:-6.02433
# Iteration: 96721/918000 	 Elapsed time: 22637.43 	 Loss:-8.71523
# Iteration: 96722/918000 	 Elapsed time: 22637.66 	 Loss:-8.89993
# Iteration: 96723/918000 	 Elapsed time: 22637.83 	 Loss:-8.91499
# Iteration: 96724/918000 	 Elapsed time: 22637.99 	 Loss:-8.91554
# Iteration: 96725/918000 	 Elapsed time: 22638.20 	 Loss:-8.91301
# Iteration: 96726/918000 	 Elapsed time: 22638.50 	 Loss:-8.95901
# Iteration: 96727/918000 	 Elapsed time: 22638.64 	 Loss:-8.92248
# Iteration: 96728/918000 	 Elapsed time: 22638.83 	 Loss:-8.94979
# Iteration: 96729/918000 	 Elapsed time: 22639.00 	 Loss:-8.97024
# Iteration: 96730/918000 	 Elapsed time: 22639.15 	 Loss:-8.95663
# Iteration: 96731/918000 	 Elapsed time: 22639.32 	 Loss:-1.38377
# Iteration: 96732/918000 	 Elapsed time: 22639.48 	 Loss:-3.36378
# Iteration: 96733/918000 	 Elapsed time: 22639.62 	 Loss:-8.49778
# Iteration: 96734/918000 	 Elapsed time: 22639.77 	 Loss:-8.34077
# Iteration: 96735/918000 	 Elapsed time: 22639.94 	 Loss:-8.72061
# Iteration: 96736/918000 	 Elapsed time: 22640.10 	 Loss:-8.74252
# Iteration: 96737/918000 	 Elapsed time: 22640.31 	 Loss:-8.76332
# Iteration: 96738/918000 	 Elapsed time: 22640.46 	 Loss:-8.80036
# Iteration: 96739/918000 	 Elapsed time: 22640.61 	 Loss:-8.67711
# Iteration: 96740/918000 	 Elapsed time: 22640.77 	 Loss:-8.66428
# Iteration: 96741/918000 	 Elapsed time: 22640.93 	 Loss:-8.84934
# Iteration: 96742/918000 	 Elapsed time: 22641.11 	 Loss:-8.84883
# Iteration: 96743/918000 	 Elapsed time: 22641.28 	 Loss:-3.11441
# Iteration: 96744/918000 	 Elapsed time: 22641.48 	 Loss:-8.77550
# Iteration: 96745/918000 	 Elapsed time: 22641.66 	 Loss:-8.93768
# Iteration: 96746/918000 	 Elapsed time: 22641.80 	 Loss:-8.82771
# Iteration: 96747/918000 	 Elapsed time: 22641.97 	 Loss:-8.77531
# Iteration: 96748/918000 	 Elapsed time: 22642.12 	 Loss:3.94982
# Iteration: 96749/918000 	 Elapsed time: 22642.37 	 Loss:-8.76824
# Iteration: 96750/918000 	 Elapsed time: 22642.63 	 Loss:1.37814
# Iteration: 96751/918000 	 Elapsed time: 22642.87 	 Loss:-8.13040
# Iteration: 96752/918000 	 Elapsed time: 22643.03 	 Loss:-8.31681
# Iteration: 96753/918000 	 Elapsed time: 22643.20 	 Loss:-8.79565
# Iteration: 96754/918000 	 Elapsed time: 22643.36 	 Loss:-8.73476
# Iteration: 96755/918000 	 Elapsed time: 22643.52 	 Loss:-7.45563
# Iteration: 96756/918000 	 Elapsed time: 22643.67 	 Loss:-6.77644
# Iteration: 96757/918000 	 Elapsed time: 22643.82 	 Loss:-8.68382
# Iteration: 96758/918000 	 Elapsed time: 22643.96 	 Loss:-8.24691
# Iteration: 96759/918000 	 Elapsed time: 22644.12 	 Loss:-8.54375
# Iteration: 96760/918000 	 Elapsed time: 22644.26 	 Loss:-8.86027
# Iteration: 96761/918000 	 Elapsed time: 22644.44 	 Loss:-8.55923
# Iteration: 96762/918000 	 Elapsed time: 22644.62 	 Loss:-3.97599
# Iteration: 96763/918000 	 Elapsed time: 22644.78 	 Loss:3.65693
# Iteration: 96764/918000 	 Elapsed time: 22644.95 	 Loss:-8.36609
# Iteration: 96765/918000 	 Elapsed time: 22645.10 	 Loss:-8.40411
# Iteration: 96766/918000 	 Elapsed time: 22645.26 	 Loss:-8.20622
# Iteration: 96767/918000 	 Elapsed time: 22645.41 	 Loss:-7.03198
# Iteration: 96768/918000 	 Elapsed time: 22645.59 	 Loss:-8.69872
# Iteration: 96769/918000 	 Elapsed time: 22645.74 	 Loss:-8.80880
# Iteration: 96770/918000 	 Elapsed time: 22645.89 	 Loss:-8.60448
# Iteration: 96771/918000 	 Elapsed time: 22646.04 	 Loss:-8.70709
# Iteration: 96772/918000 	 Elapsed time: 22646.18 	 Loss:-8.83027
# Iteration: 96773/918000 	 Elapsed time: 22646.33 	 Loss:-0.96281
# Iteration: 96774/918000 	 Elapsed time: 22646.47 	 Loss:-8.88311
# Iteration: 96775/918000 	 Elapsed time: 22646.63 	 Loss:-5.95798
# Iteration: 96776/918000 	 Elapsed time: 22646.79 	 Loss:-8.85397
# Iteration: 96777/918000 	 Elapsed time: 22646.94 	 Loss:-8.89290
# Iteration: 96778/918000 	 Elapsed time: 22647.09 	 Loss:-8.76875
# Iteration: 96779/918000 	 Elapsed time: 22647.58 	 Loss:-8.82986
# Iteration: 96780/918000 	 Elapsed time: 22647.76 	 Loss:-8.89238
# Iteration: 96781/918000 	 Elapsed time: 22647.98 	 Loss:-8.91680
# Iteration: 96782/918000 	 Elapsed time: 22648.12 	 Loss:-8.93757
# Iteration: 96783/918000 	 Elapsed time: 22648.27 	 Loss:-8.91162
# Iteration: 96784/918000 	 Elapsed time: 22648.43 	 Loss:-8.20253
# Iteration: 96785/918000 	 Elapsed time: 22648.57 	 Loss:-0.05486
# Iteration: 96786/918000 	 Elapsed time: 22648.73 	 Loss:-8.70273
# Iteration: 96787/918000 	 Elapsed time: 22648.90 	 Loss:-8.44879
# Iteration: 96788/918000 	 Elapsed time: 22649.05 	 Loss:-8.67257
# Iteration: 96789/918000 	 Elapsed time: 22649.20 	 Loss:-4.71415
# Iteration: 96790/918000 	 Elapsed time: 22649.37 	 Loss:-8.76327
# Iteration: 96791/918000 	 Elapsed time: 22649.54 	 Loss:-8.88546
# Iteration: 96792/918000 	 Elapsed time: 22649.72 	 Loss:-0.05533
# Iteration: 96793/918000 	 Elapsed time: 22649.87 	 Loss:-2.44453
# Iteration: 96794/918000 	 Elapsed time: 22650.03 	 Loss:-8.91432
# Iteration: 96795/918000 	 Elapsed time: 22650.18 	 Loss:-8.89535
# Iteration: 96796/918000 	 Elapsed time: 22650.35 	 Loss:-8.92976
# Iteration: 96797/918000 	 Elapsed time: 22650.51 	 Loss:-8.91296
# Iteration: 96798/918000 	 Elapsed time: 22650.66 	 Loss:-8.85901
# Iteration: 96799/918000 	 Elapsed time: 22650.81 	 Loss:-8.92231
# Iteration: 96800/918000 	 Elapsed time: 22650.98 	 Loss:-8.89468
# Iteration: 96801/918000 	 Elapsed time: 22651.14 	 Loss:13.29170
# Iteration: 96802/918000 	 Elapsed time: 22651.29 	 Loss:-7.55084
# Iteration: 96803/918000 	 Elapsed time: 22651.44 	 Loss:-8.67830
# Iteration: 96804/918000 	 Elapsed time: 22651.59 	 Loss:-8.40500
# Iteration: 96805/918000 	 Elapsed time: 22651.73 	 Loss:-8.77300
# Iteration: 96806/918000 	 Elapsed time: 22651.95 	 Loss:-8.48775
# Iteration: 96807/918000 	 Elapsed time: 22652.10 	 Loss:-8.78391
# Iteration: 96808/918000 	 Elapsed time: 22652.29 	 Loss:-8.79087
# Iteration: 96809/918000 	 Elapsed time: 22652.46 	 Loss:14.99787
# Iteration: 96810/918000 	 Elapsed time: 22652.65 	 Loss:-8.78687
# Iteration: 96811/918000 	 Elapsed time: 22652.84 	 Loss:-0.22874
# Iteration: 96812/918000 	 Elapsed time: 22653.00 	 Loss:-8.54235
# Iteration: 96813/918000 	 Elapsed time: 22653.18 	 Loss:-8.85546
# Iteration: 96814/918000 	 Elapsed time: 22653.35 	 Loss:-8.87142
# Iteration: 96815/918000 	 Elapsed time: 22653.50 	 Loss:-8.79172
# Iteration: 96816/918000 	 Elapsed time: 22653.70 	 Loss:-7.96936
# Iteration: 96817/918000 	 Elapsed time: 22653.85 	 Loss:-8.90400
# Iteration: 96818/918000 	 Elapsed time: 22654.05 	 Loss:-6.72620
# Iteration: 96819/918000 	 Elapsed time: 22654.20 	 Loss:-8.88933

# %%
# plt.imshow(y_sample.cpu()[0][0], vmin=0, vmax=1)

# %%
import argparse
import torch
# import Learner
# import datasets
# import utils
# from CGlowModel import CondGlowModel
import matplotlib.pyplot as plt


if __name__ == "__main__":

    parser = argparse.ArgumentParser(description='predict c-Glow')

    # model parameters
    # parser.add_argument("--x_size", type=tuple, default=(3,64,64))
    # parser.add_argument("--y_size", type=tuple, default=(1,64,64))
    parser.add_argument("--x_size", type=tuple, default=(1,12)) # was (1,8) before adding 4 more
    parser.add_argument("--y_size", type=tuple, default=(1,16,16))
    parser.add_argument("--x_hidden_channels", type=int, default=128)
    parser.add_argument("--x_hidden_size", type=int, default=64)
    parser.add_argument("--y_hidden_channels", type=int, default=256)
    parser.add_argument("-K", "--depth_flow", type=int, default=8)
    parser.add_argument("-L", "--num_levels", type=int, default=3)
    parser.add_argument("--learn_top", type=bool, default=False)

    # dataset
    parser.add_argument("-d", "--dataset_name", type=str, default="horse")
    parser.add_argument("-r", "--dataset_root", type=str, default="")
    parser.add_argument("--label_scale", type=float, default=1)
    parser.add_argument("--label_bias", type=float, default=0.5)
    parser.add_argument("--num_labels", type=int, default=2)
    parser.add_argument("--x_bins", type=float, default=256.0)
    parser.add_argument("--y_bins", type=float, default=2.0)

    # output
    parser.add_argument("-o", "--out_root", type=str, default="out_dir_temp")

    # model path
    parser.add_argument("--model_path", type=str, default="/pdo/users/jlupoiii/TESS/model_conditional_norm_flow/log_20231110_0012/checkpoints/checkpoint_550000.pth.tar")

    
    # predictor parameters
    parser.add_argument("--batch_size", type=int, default=10)
    parser.add_argument("--num_samples", type=int, default=10)


    # args = parser.parse_args()
    args = parser.parse_known_args()[0]
    cuda = torch.cuda.is_available()

    # create TESS dataset
    torch.manual_seed(42)
    full_dataset = TESSDataset()
    train_ratio = 0.8
    num_train_samples = int(train_ratio * len(full_dataset))
    num_valid_samples = len(full_dataset) - num_train_samples
    training_set, valid_set = random_split(full_dataset, [num_train_samples, num_valid_samples])


    # model
    model = CondGlowModel(args)
    if cuda:
        model = model.cuda()
    state = load_state(args.model_path, cuda)
    model.load_state_dict(state["model"])
    del state

    # predictor
    predictor = Inferencer(model, valid_set, args, cuda)

    # predict
    predictor.sampled_based_prediction(args.num_samples)
# Out:
# load to gpu
# Batch IDs: 0
# Samples: 0/10
# Samples: 1/10
# Samples: 2/10
# Samples: 3/10
# Samples: 4/10
# Samples: 5/10
# Samples: 6/10
# Samples: 7/10
# Samples: 8/10
# Samples: 9/10
# Batch IDs: 1
# Samples: 0/10
# Samples: 1/10
# Samples: 2/10
# Samples: 3/10
# Samples: 4/10
# Samples: 5/10
# Samples: 6/10
# Samples: 7/10
# Samples: 8/10
# Samples: 9/10
# Batch IDs: 2
# Samples: 0/10
# Samples: 1/10
# Samples: 2/10
# Samples: 3/10
# Samples: 4/10
# Samples: 5/10
# Samples: 6/10
# Samples: 7/10
# Samples: 8/10
# Samples: 9/10
# Batch IDs: 3
# Samples: 0/10
# Samples: 1/10
# Samples: 2/10
# Samples: 3/10
# Samples: 4/10
# Samples: 5/10
# Samples: 6/10
# Samples: 7/10
# Samples: 8/10
# Samples: 9/10
# Batch IDs: 4
# Samples: 0/10
# Samples: 1/10
# Samples: 2/10
# Samples: 3/10
# Samples: 4/10
# Samples: 5/10
# Samples: 6/10
# Samples: 7/10
# Samples: 8/10
# Samples: 9/10
# Batch IDs: 5
# Samples: 0/10
# Samples: 1/10
# Samples: 2/10
# Samples: 3/10
# Samples: 4/10
# Samples: 5/10
# Samples: 6/10
# Samples: 7/10
# Samples: 8/10
# Samples: 9/10
# Batch IDs: 6
# Samples: 0/10
# Samples: 1/10
# Samples: 2/10
# Samples: 3/10
# Samples: 4/10
# Samples: 5/10
# Samples: 6/10
# Samples: 7/10
# Samples: 8/10
# Samples: 9/10
# KeyboardInterrupt
